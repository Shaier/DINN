# %% [markdown]
# # Paper: Time-optimal control strategies in SIR epidemic models

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %% [markdown]
# # Vaccination
# Parameters:
# alpha1 = 1
# alpha2 = 0
# beta = 0.0075
# mu = 5
# u = 0.515151515
# tao = 0.58

# %%
# Initial number of infected individuals, I0
I0 = 1
# Everyone else, S0, is susceptible to infection initially.
S0 = 2000
# A grid of time points (in days)
t = np.linspace(0, 3, 100) 
#parameters
alpha1 = 1
alpha2 = 0
beta = 0.0075
mu = 5
u = 0.515151515
tao = 0.58

# The SIR model differential equations.
def deriv(y, t, beta, mu, u, tao, alpha1, alpha2):
    S, I = y
    dSdt = -beta * S * I + u * (t > tao) * alpha1 * (-S)
    dIdt = beta * S * I - mu * I + u * (t > tao) * alpha2 * (-I)
    return dSdt, dIdt


# Initial conditions vector
y0 = S0, I0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(beta, mu, u, tao, alpha1, alpha2))
S, I = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(t, I, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#save to csv file
a = np.asarray([t, S, I ]) 

#np.savetxt("tSI_vaccination_data.csv", a, delimiter=",")

# %% [markdown]
# # Isolation
# Parameters:
# alpha1 = 0
# alpha2 = 1
# beta = 0.005
# mu = 5
# u = 2.06
# tao = 1.58

# %%
# Initial number of infected individuals, I0
I0 = 1
# Everyone else, S0, is susceptible to infection initially.
S0 = 2000
# A grid of time points (in days)
t = np.linspace(0, 3, 100) 
#parameters
alpha1 = 0
alpha2 = 1
beta = 0.005
mu = 5
u = 2.06
tao = 1.58

# The SIR model differential equations.
def deriv(y, t, beta, mu, u, tao, alpha1, alpha2):
    S, I = y
    dSdt = -beta * S * I + u * (t > tao) * alpha1 * (-S)
    dIdt = beta * S * I - mu * I + u * (t > tao) * alpha2 * (-I)
    return dSdt, dIdt


# Initial conditions vector
y0 = S0, I0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(beta, mu, u, tao, alpha1, alpha2))
S, I = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(t, I, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#save to csv file
a = np.asarray([t, S, I ]) 

#np.savetxt("tSI_iso_data.csv", a, delimiter=",")

# %% [markdown]
# # Culling
# Parameters:
# alpha1 = 1
# alpha2 = 1
# beta = 0.0075
# mu = 5
# u = 0.5152
# tao = 0.64

# %%
# Initial number of infected individuals, I0
I0 = 1
# Everyone else, S0, is susceptible to infection initially.
S0 = 2000
# A grid of time points (in days)
t = np.linspace(0, 3, 100) 
#parameters
alpha1 = 1
alpha2 = 1
beta = 0.0075
mu = 5
u = 0.5152
tao = 0.64

# The SIR model differential equations.
def deriv(y, t, beta, mu, u, tao, alpha1, alpha2):
    S, I = y
    dSdt = -beta * S * I + u * (t > tao) * alpha1 * (-S)
    dIdt = beta * S * I - mu * I + u * (t > tao) * alpha2 * (-I)
    return dSdt, dIdt


# Initial conditions vector
y0 = S0, I0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(beta, mu, u, tao, alpha1, alpha2))
S, I = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(t, I, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#save to csv file
a = np.asarray([t, S, I ]) 

#np.savetxt("tSI_cul_data.csv", a, delimiter=",")

# %% [markdown]
# # Reduction
# Parameters:
# alpha1 = beta*S*I
# alpha2 = beta*S*I
# beta = 0.005
# mu = 5
# u = 0.404
# tao = 1.41

# %%
import torch
# Initial number of infected individuals, I0
I0 = 1
# Everyone else, S0, is susceptible to infection initially.
S0 = 2000
# A grid of time points (in days)
t = np.linspace(0, 3, 100) 
#parameters
beta = 0.005
mu = 5
u = 0.404
tao = 1.41


# The SIR model differential equations.
def deriv(y, t, beta, mu, u, tao):
    S, I = y
    #dSdt = -beta * S * I + u * torch.sigmoid(-1e2*(torch.tensor(tao) - torch.tensor(t))) * (-beta) * S * I
    dSdt = -beta * S * I + u * (t > tao) * (-beta) * S * I
    #dIdt = beta * S * I - mu * I + u * torch.sigmoid(-1e2*(torch.tensor(tao) - torch.tensor(t))) * (-beta) * S * I
    dIdt = beta * S * I - mu * I + u * (t > tao) * (-beta) * S * I
    return dSdt, dIdt


# Initial conditions vector
y0 = S0, I0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(beta, mu, u, tao))
S, I = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(t, I, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#save to csv file
a = np.asarray([t, S, I ]) 

#np.savetxt("tSI_red_data.csv", a, delimiter=",")

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class model(nn.Module): 
        def __init__(self):
            super(model, self).__init__()
            #self.a = torch.nn.Parameter(torch.rand(1, requires_grad=True))
            #self.a = torch.tensor( [[ torch.nn.Parameter(torch.rand(1, requires_grad=True)) ] for i in range(5)], requires_grad=True)
            self.a = torch.nn.Parameter(torch.rand(7, requires_grad=True))
            self.b = torch.nn.Parameter(torch.rand(1, requires_grad=True))
            self.c = torch.nn.Parameter(torch.rand(1, requires_grad=True))

        def train(self):
          print('training...')
          for epoch in range(3):
            #print(self.a, self.b, self.c)
            print(self.a)
            for r in range(5):
              optimizer.zero_grad()
              loss = torch.square(5 * (r > 2) * (3) - model_net.a[1] * torch.sigmoid((r - model_net.b)) * (model_net.c))
              loss.backward(retain_graph=True) #accumulate gradients

            
            optimizer.step() 
          


model_net = model()
optimizer = optim.Adam(model_net.parameters(), lr = 0.1)

print(model_net.a)
print('')
model_net.train()
# Out:
# Parameter containing:
# tensor([0.3217, 0.7666, 0.9859, 0.1571, 0.1769, 0.7512, 0.9485],
#        requires_grad=True)
#
# training...
# Parameter containing:
# tensor([0.3217, 0.7666, 0.9859, 0.1571, 0.1769, 0.7512, 0.9485],
#        requires_grad=True)
# Parameter containing:
# tensor([0.3217, 0.8666, 0.9859, 0.1571, 0.1769, 0.7512, 0.9485],
#        requires_grad=True)
# Parameter containing:
# tensor([0.3217, 0.9666, 0.9859, 0.1571, 0.1769, 0.7512, 0.9485],
#        requires_grad=True)

# %%
#testing stuff below. delete it later

# %%
import torch
d = []
for i in range (10000):
    d.append(torch.rand(1) * 0.01 )

#0.5
#2

print(min(d))
print(max(d))
# Out:
# tensor([2.6840e-06])
# tensor([0.0100])

# %%
#autograd
import torch
from torch.autograd import grad
import torch.nn as nn
import torch.optim as optim

class net_x(nn.Module): 
        def __init__(self):
            super(net_x, self).__init__()
            self.fc1=nn.Linear(1, 20) 
            self.fc2=nn.Linear(20, 20)
            self.out=nn.Linear(20, 10) #SI

        def forward(self, x):
            x=torch.tanh(self.fc1(x))
            x=torch.tanh(self.fc2(x))
            x=self.out(x)
            return x

nx = net_x()
t = torch.rand(1000, requires_grad = True) #input vector
t = torch.reshape(t, (1000,1)) #reshape for batch

# %%
# %%time 
#method 1
for timestep in t:
     y = nx(timestep) 
     #print('y ', y)
     #print(grad(y[0],timestep, retain_graph=True)) #0 for the first vector (i.e "S"), 1 for the 2nd vector (i.e "I")
     for i in range(10):
         grad(y[i],timestep, retain_graph=True) #0 for the first vector (i.e "S"), 1 for the 2nd vector (i.e "I")
# Out:
# CPU times: user 1.08 s, sys: 2.83 ms, total: 1.08 s
# Wall time: 1.08 s

# %%
# %%time 
#method 2
vals = []

def get_SI(t_):
    net_vals = nx(t_)
    vals.append(net_vals)
    return net_vals

dx = torch.autograd.functional.jacobian(get_SI, t)

#Jacobian method
#dx = torch.autograd.functional.jacobian(lambda t_: nx(t_), t)
#then just take the vectors (S,I...)
#dx = torch.diagonal(torch.diagonal(dx, 0, -1), 0)[0] #first vector
#dx = torch.diagonal(torch.diagonal(dx, 1, -1), 0)[0] #2nd vector
#dx = torch.diagonal(torch.diagonal(dx, 2, -1), 0)[0] #3 vector
#dx = torch.diagonal(torch.diagonal(dx, 3, -1), 0)[0] #2nd vector
#dx
#print(vals[0])
#print('\nS: ' , vals[0][:,0])
# Out:
# CPU times: user 1.92 s, sys: 52.6 ms, total: 1.97 s
# Wall time: 1.97 s

# %%
a = range(100)
b = range(100)
c = range(100)
d = range(100)
my_tensor = torch.tensor([a,b,c,d])

t = range(100)

#derivative = grad(my_tensor, t) --> not working

#Instead what I'm currently doing:
for i in range(len(t)):
    a_grad = grad(a[i],t[i], retain_graph=True)
    #b_grad = grad(b[i],t[i], retain_graph=True)
    #etc.
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-4f9a41537b92> in <module>
#      12 for i in range(len(t)):
#      13     print(a[i])
# ---> 14     a_grad = grad(a[i],t[i], retain_graph=True)
#      15     #b_grad = grad(b[i],t[i], retain_graph=True)
#      16     #etc.
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     194             is an error. Defaults to ``False``.
#     195     """
# --> 196     outputs = (outputs,) if isinstance(outputs, torch.Tensor) else tuple(outputs)
#     197     inputs = (inputs,) if isinstance(inputs, torch.Tensor) else tuple(inputs)
#     198     overridable_args = outputs + inputs
#
# TypeError: 'int' object is not iterable
