# %%
#Mount my drive- run the code, go to the link, accept.
from google.colab import drive
drive.mount('/content/gdrive')

#Change working directory to make it easier to access the files
import os
os.chdir("/content/gdrive/My Drive/Colab Notebooks/dinn/experiments/learning_rates")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# '/content/gdrive/My Drive/Colab Notebooks/dinn/experiments/learning_rates'

# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('covid_100_pts.csv', delimiter=',') #in the form of [t,S,I,D,R]

torch.manual_seed(1234)

# %%
# %%time

PATH = 'covid_lr8_step_10000_' 

class DINN(nn.Module):
    def __init__(self, t, S_data, I_data, D_data, R_data): #[t,S,I,D,R]
        super(DINN, self).__init__()
        self.N = 59e6 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.I = torch.tensor(I_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 3 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True)) #0.191
        self.beta_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True)) #0.05
        self.gamma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True)) #0.0294
        
        #find values for normalization
        self.S_max = max(self.S)
        self.I_max = max(self.I)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.I_min = min(self.I)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #unnormalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x4 for S,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 4)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 4)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 4)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 4)); self.m4[:, 3] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda, self.gamma_tilda]))

    #force parameters to be in a range
    @property
    def alpha(self):
        return torch.tanh(self.alpha_tilda)*0.191*20

    @property
    def beta(self):
        return torch.tanh(self.beta_tilda)*0.05*20
    
    @property
    def gamma(self):
        return torch.tanh(self.gamma_tilda)*0.0294*20


    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
             
             
             
            
            self.out=nn.Linear(20, 4) #outputs S, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            
            
            
            
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, I_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m2, retain_graph=True)
        
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m3, retain_graph=True)
        
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m4, retain_graph=True)
        
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-(self.alpha / self.N) * S * I)  / (self.S_max - self.S_min)
        f2_hat = I_hat_t - ((self.alpha / self.N) * S * I - self.beta * I - self.gamma * I ) / (self.I_max - self.I_min)
        f3_hat = D_hat_t - (self.gamma * I) / (self.D_max - self.D_min)
        f4_hat = R_hat_t - (self.beta * I ) / (self.R_max - self.R_min)


        return f1_hat, f2_hat, f3_hat, f4_hat, S_hat, I_hat, D_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
         
        self.losses = checkpoint['losses']
         
         

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        I_pred_list = []
        D_pred_list = []
        R_pred_list = []

         
        f1, f2, f3, f4, S_pred, I_pred, D_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        loss = (torch.mean(torch.square(self.S_hat - S_pred))+ 
                torch.mean(torch.square(self.I_hat - I_pred))+
                torch.mean(torch.square(self.D_hat - D_pred))+
                torch.mean(torch.square(self.R_hat - R_pred))+
                torch.mean(torch.square(f1))+
                torch.mean(torch.square(f2))+
                torch.mean(torch.square(f3))+
                torch.mean(torch.square(f4))
                ) 

         
        loss.backward()
        self.optimizer.step()
        self.scheduler.step() 
         
         

        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)

        #loss + model parameters update
        if epoch % 4000 == 0:
          #checkpoint save every 100 epochs if the loss is lower
          print('\nSaving model... Loss is: ', loss)
          torch.save({
              'epoch': epoch,
              'model': self.state_dict(),
              'optimizer_state_dict': self.optimizer.state_dict(),
              'scheduler': self.scheduler.state_dict(),
              #'loss': loss,
              'losses': self.losses,
              }, PATH + str(self.save)+'.pt')
          if self.save % 2 > 0: #its on 3
            self.save = 2 #change to 2
          else: #its on 2
            self.save = 3 #change to 3

          print('epoch: ', epoch)
          print('alpha: (goal 0.191 ', self.alpha)
          print('beta: (goal 0.05 ', self.beta)
          print('gamma: (goal 0.0294 ', self.gamma)

          if loss < 4e-4:
            break

           

        
       
       
       
       
      return S_pred_list, I_pred_list, D_pred_list, R_pred_list
# Out:
# CPU times: user 50 µs, sys: 0 ns, total: 50 µs
# Wall time: 53.6 µs

# %%
# %%time

 
dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[3], 
            sidr_data[4]) #in the form of [t,S,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

 
#scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-9, max_lr=1e-5, step_size_up=20000, mode="triangular2", cycle_momentum=False)
scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-8, max_lr=1e-3, step_size_up=10000, mode="exp_range", gamma=0.85, cycle_momentum=False)

dinn.scheduler = scheduler

try: 
  S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(1400000) #train
except EOFError:
  if dinn.save == 2:
    dinn.save = 3
    S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(1400000) #train
  elif dinn.save == 3:
    dinn.save = 2
    S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(1400000) #train
# Out:
# loading pre-trained model...
#
# starting training...
#
#
# Epoch  0
#
# Saving model... Loss is:  tensor(0.5166, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  0
# alpha: (goal 0.191  tensor([0.1741], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1000
#
# Epoch  2000
#
# Epoch  3000
#
# Epoch  4000
#
# Saving model... Loss is:  tensor(0.5155, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  4000
# alpha: (goal 0.191  tensor([0.1743], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  5000
#
# Epoch  6000
#
# Epoch  7000
#
# Epoch  8000
#
# Saving model... Loss is:  tensor(0.5143, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  8000
# alpha: (goal 0.191  tensor([0.1744], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  9000
#
# Epoch  10000
#
# Epoch  11000
#
# Epoch  12000
#
# Saving model... Loss is:  tensor(0.5132, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  12000
# alpha: (goal 0.191  tensor([0.1746], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  13000
#
# Epoch  14000
#
# Epoch  15000
#
# Epoch  16000
#
# Saving model... Loss is:  tensor(0.5121, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  16000
# alpha: (goal 0.191  tensor([0.1748], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  17000
#
# Epoch  18000
#
# Epoch  19000
#
# Epoch  20000
#
# Saving model... Loss is:  tensor(0.5110, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  20000
# alpha: (goal 0.191  tensor([0.1749], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  21000
#
# Epoch  22000
#
# Epoch  23000
#
# Epoch  24000
#
# Saving model... Loss is:  tensor(0.5100, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  24000
# alpha: (goal 0.191  tensor([0.1751], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  25000
#
# Epoch  26000
#
# Epoch  27000
#
# Epoch  28000
#
# Saving model... Loss is:  tensor(0.5089, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  28000
# alpha: (goal 0.191  tensor([0.1753], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  29000
#
# Epoch  30000
#
# Epoch  31000
#
# Epoch  32000
#
# Saving model... Loss is:  tensor(0.5079, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  32000
# alpha: (goal 0.191  tensor([0.1755], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  33000
#
# Epoch  34000
#
# Epoch  35000
#
# Epoch  36000
#
# Saving model... Loss is:  tensor(0.5069, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  36000
# alpha: (goal 0.191  tensor([0.1756], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  37000
#
# Epoch  38000
#
# Epoch  39000
#
# Epoch  40000
#
# Saving model... Loss is:  tensor(0.5059, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  40000
# alpha: (goal 0.191  tensor([0.1758], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  41000
#
# Epoch  42000
#
# Epoch  43000
#
# Epoch  44000
#
# Saving model... Loss is:  tensor(0.5050, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  44000
# alpha: (goal 0.191  tensor([0.1760], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  45000
#
# Epoch  46000
#
# Epoch  47000
#
# Epoch  48000
#
# Saving model... Loss is:  tensor(0.5040, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  48000
# alpha: (goal 0.191  tensor([0.1761], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  49000
#
# Epoch  50000
#
# Epoch  51000
#
# Epoch  52000
#
# Saving model... Loss is:  tensor(0.5031, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  52000
# alpha: (goal 0.191  tensor([0.1763], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  53000
#
# Epoch  54000
#
# Epoch  55000
#
# Epoch  56000
#
# Saving model... Loss is:  tensor(0.5022, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  56000
# alpha: (goal 0.191  tensor([0.1765], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  57000
#
# Epoch  58000
#
# Epoch  59000
#
# Epoch  60000
#
# Saving model... Loss is:  tensor(0.5013, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  60000
# alpha: (goal 0.191  tensor([0.1767], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  61000
#
# Epoch  62000
#
# Epoch  63000
#
# Epoch  64000
#
# Saving model... Loss is:  tensor(0.5005, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  64000
# alpha: (goal 0.191  tensor([0.1768], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  65000
#
# Epoch  66000
#
# Epoch  67000
#
# Epoch  68000
#
# Saving model... Loss is:  tensor(0.4996, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  68000
# alpha: (goal 0.191  tensor([0.1770], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  69000
#
# Epoch  70000
#
# Epoch  71000
#
# Epoch  72000
#
# Saving model... Loss is:  tensor(0.4988, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  72000
# alpha: (goal 0.191  tensor([0.1772], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  73000
#
# Epoch  74000
#
# Epoch  75000
#
# Epoch  76000
#
# Saving model... Loss is:  tensor(0.4980, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  76000
# alpha: (goal 0.191  tensor([0.1773], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  77000
#
# Epoch  78000
#
# Epoch  79000
#
# Epoch  80000
#
# Saving model... Loss is:  tensor(0.4972, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  80000
# alpha: (goal 0.191  tensor([0.1775], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  81000
#
# Epoch  82000
#
# Epoch  83000
#
# Epoch  84000
#
# Saving model... Loss is:  tensor(0.4965, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  84000
# alpha: (goal 0.191  tensor([0.1777], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  85000
#
# Epoch  86000
#
# Epoch  87000
#
# Epoch  88000
#
# Saving model... Loss is:  tensor(0.4957, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  88000
# alpha: (goal 0.191  tensor([0.1778], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  89000
#
# Epoch  90000
#
# Epoch  91000
#
# Epoch  92000
#
# Saving model... Loss is:  tensor(0.4950, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  92000
# alpha: (goal 0.191  tensor([0.1780], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  93000
#
# Epoch  94000
#
# Epoch  95000
#
# Epoch  96000
#
# Saving model... Loss is:  tensor(0.4943, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  96000
# alpha: (goal 0.191  tensor([0.1782], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  97000
#
# Epoch  98000
#
# Epoch  99000
#
# Epoch  100000
#
# Saving model... Loss is:  tensor(0.4936, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  100000
# alpha: (goal 0.191  tensor([0.1784], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  101000
#
# Epoch  102000
#
# Epoch  103000
#
# Epoch  104000
#
# Saving model... Loss is:  tensor(0.4929, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  104000
# alpha: (goal 0.191  tensor([0.1785], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  105000
#
# Epoch  106000
#
# Epoch  107000
#
# Epoch  108000
#
# Saving model... Loss is:  tensor(0.4923, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  108000
# alpha: (goal 0.191  tensor([0.1787], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  109000
#
# Epoch  110000
#
# Epoch  111000
#
# Epoch  112000
#
# Saving model... Loss is:  tensor(0.4917, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  112000
# alpha: (goal 0.191  tensor([0.1789], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  113000
#
# Epoch  114000
#
# Epoch  115000
#
# Epoch  116000
#
# Saving model... Loss is:  tensor(0.4911, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  116000
# alpha: (goal 0.191  tensor([0.1790], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  117000
#
# Epoch  118000
#
# Epoch  119000
#
# Epoch  120000
#
# Saving model... Loss is:  tensor(0.4905, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  120000
# alpha: (goal 0.191  tensor([0.1792], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  121000
#
# Epoch  122000
#
# Epoch  123000
#
# Epoch  124000
#
# Saving model... Loss is:  tensor(0.4899, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  124000
# alpha: (goal 0.191  tensor([0.1794], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  125000
#
# Epoch  126000
#
# Epoch  127000
#
# Epoch  128000
#
# Saving model... Loss is:  tensor(0.4894, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  128000
# alpha: (goal 0.191  tensor([0.1795], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  129000
#
# Epoch  130000
#
# Epoch  131000
#
# Epoch  132000
#
# Saving model... Loss is:  tensor(0.4889, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  132000
# alpha: (goal 0.191  tensor([0.1797], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  133000
#
# Epoch  134000
#
# Epoch  135000
#
# Epoch  136000
#
# Saving model... Loss is:  tensor(0.4884, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  136000
# alpha: (goal 0.191  tensor([0.1799], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  137000
#
# Epoch  138000
#
# Epoch  139000
#
# Epoch  140000
#
# Saving model... Loss is:  tensor(0.4879, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  140000
# alpha: (goal 0.191  tensor([0.1801], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  141000
#
# Epoch  142000
#
# Epoch  143000
#
# Epoch  144000
#
# Saving model... Loss is:  tensor(0.4874, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  144000
# alpha: (goal 0.191  tensor([0.1802], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  145000
#
# Epoch  146000
#
# Epoch  147000
#
# Epoch  148000
#
# Saving model... Loss is:  tensor(0.4870, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  148000
# alpha: (goal 0.191  tensor([0.1804], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  149000
#
# Epoch  150000
#
# Epoch  151000
#
# Epoch  152000
#
# Saving model... Loss is:  tensor(0.4865, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  152000
# alpha: (goal 0.191  tensor([0.1806], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  153000
#
# Epoch  154000
#
# Epoch  155000
#
# Epoch  156000
#
# Saving model... Loss is:  tensor(0.4861, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  156000
# alpha: (goal 0.191  tensor([0.1807], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  157000
#
# Epoch  158000
#
# Epoch  159000
#
# Epoch  160000
#
# Saving model... Loss is:  tensor(0.4857, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  160000
# alpha: (goal 0.191  tensor([0.1809], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  161000
#
# Epoch  162000
#
# Epoch  163000
#
# Epoch  164000
#
# Saving model... Loss is:  tensor(0.4854, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  164000
# alpha: (goal 0.191  tensor([0.1811], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  165000
#
# Epoch  166000
#
# Epoch  167000
#
# Epoch  168000
#
# Saving model... Loss is:  tensor(0.4850, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  168000
# alpha: (goal 0.191  tensor([0.1813], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  169000
#
# Epoch  170000
#
# Epoch  171000
#
# Epoch  172000
#
# Saving model... Loss is:  tensor(0.4847, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  172000
# alpha: (goal 0.191  tensor([0.1814], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  173000
#
# Epoch  174000
#
# Epoch  175000
#
# Epoch  176000
#
# Saving model... Loss is:  tensor(0.4844, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  176000
# alpha: (goal 0.191  tensor([0.1816], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  177000
#
# Epoch  178000
#
# Epoch  179000
#
# Epoch  180000
#
# Saving model... Loss is:  tensor(0.4841, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  180000
# alpha: (goal 0.191  tensor([0.1818], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  181000
#
# Epoch  182000
#
# Epoch  183000
#
# Epoch  184000
#
# Saving model... Loss is:  tensor(0.4839, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  184000
# alpha: (goal 0.191  tensor([0.1819], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  185000
#
# Epoch  186000
#
# Epoch  187000
#
# Epoch  188000
#
# Saving model... Loss is:  tensor(0.4836, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  188000
# alpha: (goal 0.191  tensor([0.1821], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  189000
#
# Epoch  190000
#
# Epoch  191000
#
# Epoch  192000
#
# Saving model... Loss is:  tensor(0.4834, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  192000
# alpha: (goal 0.191  tensor([0.1823], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  193000
#
# Epoch  194000
#
# Epoch  195000
#
# Epoch  196000
#
# Saving model... Loss is:  tensor(0.4832, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  196000
# alpha: (goal 0.191  tensor([0.1824], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  197000
#
# Epoch  198000
#
# Epoch  199000
#
# Epoch  200000
#
# Saving model... Loss is:  tensor(0.4830, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  200000
# alpha: (goal 0.191  tensor([0.1826], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  201000
#
# Epoch  202000
#
# Epoch  203000
#
# Epoch  204000
#
# Saving model... Loss is:  tensor(0.4828, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  204000
# alpha: (goal 0.191  tensor([0.1828], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  205000
#
# Epoch  206000
#
# Epoch  207000
#
# Epoch  208000
#
# Saving model... Loss is:  tensor(0.4827, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  208000
# alpha: (goal 0.191  tensor([0.1830], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  209000
#
# Epoch  210000
#
# Epoch  211000
#
# Epoch  212000
#
# Saving model... Loss is:  tensor(0.4825, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  212000
# alpha: (goal 0.191  tensor([0.1831], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  213000
#
# Epoch  214000
#
# Epoch  215000
#
# Epoch  216000
#
# Saving model... Loss is:  tensor(0.4823, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  216000
# alpha: (goal 0.191  tensor([0.1833], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  217000
#
# Epoch  218000
#
# Epoch  219000
#
# Epoch  220000
#
# Saving model... Loss is:  tensor(0.4822, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  220000
# alpha: (goal 0.191  tensor([0.1835], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  221000
#
# Epoch  222000
#
# Epoch  223000
#
# Epoch  224000
#
# Saving model... Loss is:  tensor(0.4820, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  224000
# alpha: (goal 0.191  tensor([0.1836], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  225000
#
# Epoch  226000
#
# Epoch  227000
#
# Epoch  228000
#
# Saving model... Loss is:  tensor(0.4819, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  228000
# alpha: (goal 0.191  tensor([0.1838], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  229000
#
# Epoch  230000
#
# Epoch  231000
#
# Epoch  232000
#
# Saving model... Loss is:  tensor(0.4817, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  232000
# alpha: (goal 0.191  tensor([0.1840], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  233000
#
# Epoch  234000
#
# Epoch  235000
#
# Epoch  236000
#
# Saving model... Loss is:  tensor(0.4815, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  236000
# alpha: (goal 0.191  tensor([0.1841], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  237000
#
# Epoch  238000
#
# Epoch  239000
#
# Epoch  240000
#
# Saving model... Loss is:  tensor(0.4814, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  240000
# alpha: (goal 0.191  tensor([0.1843], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  241000
#
# Epoch  242000
#
# Epoch  243000
#
# Epoch  244000
#
# Saving model... Loss is:  tensor(0.4812, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  244000
# alpha: (goal 0.191  tensor([0.1845], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  245000
#
# Epoch  246000
#
# Epoch  247000
#
# Epoch  248000
#
# Saving model... Loss is:  tensor(0.4811, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  248000
# alpha: (goal 0.191  tensor([0.1847], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  249000
#
# Epoch  250000
#
# Epoch  251000
#
# Epoch  252000
#
# Saving model... Loss is:  tensor(0.4809, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  252000
# alpha: (goal 0.191  tensor([0.1848], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  253000
#
# Epoch  254000
#
# Epoch  255000
#
# Epoch  256000
#
# Saving model... Loss is:  tensor(0.4807, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  256000
# alpha: (goal 0.191  tensor([0.1850], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  257000
#
# Epoch  258000
#
# Epoch  259000
#
# Epoch  260000
#
# Saving model... Loss is:  tensor(0.4806, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  260000
# alpha: (goal 0.191  tensor([0.1852], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  261000
#
# Epoch  262000
#
# Epoch  263000
#
# Epoch  264000
#
# Saving model... Loss is:  tensor(0.4804, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  264000
# alpha: (goal 0.191  tensor([0.1853], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  265000
#
# Epoch  266000
#
# Epoch  267000
#
# Epoch  268000
#
# Saving model... Loss is:  tensor(0.4803, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  268000
# alpha: (goal 0.191  tensor([0.1855], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  269000
#
# Epoch  270000
#
# Epoch  271000
#
# Epoch  272000
#
# Saving model... Loss is:  tensor(0.4801, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  272000
# alpha: (goal 0.191  tensor([0.1857], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  273000
#
# Epoch  274000
#
# Epoch  275000
#
# Epoch  276000
#
# Saving model... Loss is:  tensor(0.4800, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  276000
# alpha: (goal 0.191  tensor([0.1859], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  277000
#
# Epoch  278000
#
# Epoch  279000
#
# Epoch  280000
#
# Saving model... Loss is:  tensor(0.4798, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  280000
# alpha: (goal 0.191  tensor([0.1860], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  281000
#
# Epoch  282000
#
# Epoch  283000
#
# Epoch  284000
#
# Saving model... Loss is:  tensor(0.4796, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  284000
# alpha: (goal 0.191  tensor([0.1862], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  285000
#
# Epoch  286000
#
# Epoch  287000
#
# Epoch  288000
#
# Saving model... Loss is:  tensor(0.4795, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  288000
# alpha: (goal 0.191  tensor([0.1864], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  289000
#
# Epoch  290000
#
# Epoch  291000
#
# Epoch  292000
#
# Saving model... Loss is:  tensor(0.4793, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  292000
# alpha: (goal 0.191  tensor([0.1865], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  293000
#
# Epoch  294000
#
# Epoch  295000
#
# Epoch  296000
#
# Saving model... Loss is:  tensor(0.4792, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  296000
# alpha: (goal 0.191  tensor([0.1867], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  297000
#
# Epoch  298000
#
# Epoch  299000
#
# Epoch  300000
#
# Saving model... Loss is:  tensor(0.4790, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  300000
# alpha: (goal 0.191  tensor([0.1869], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  301000
#
# Epoch  302000
#
# Epoch  303000
#
# Epoch  304000
#
# Saving model... Loss is:  tensor(0.4789, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  304000
# alpha: (goal 0.191  tensor([0.1870], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  305000
#
# Epoch  306000
#
# Epoch  307000
#
# Epoch  308000
#
# Saving model... Loss is:  tensor(0.4787, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  308000
# alpha: (goal 0.191  tensor([0.1872], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  309000
#
# Epoch  310000
#
# Epoch  311000
#
# Epoch  312000
#
# Saving model... Loss is:  tensor(0.4785, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  312000
# alpha: (goal 0.191  tensor([0.1874], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  313000
#
# Epoch  314000
#
# Epoch  315000
#
# Epoch  316000
#
# Saving model... Loss is:  tensor(0.4784, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  316000
# alpha: (goal 0.191  tensor([0.1876], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  317000
#
# Epoch  318000
#
# Epoch  319000
#
# Epoch  320000
#
# Saving model... Loss is:  tensor(0.4782, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  320000
# alpha: (goal 0.191  tensor([0.1877], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  321000
#
# Epoch  322000
#
# Epoch  323000
#
# Epoch  324000
#
# Saving model... Loss is:  tensor(0.4781, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  324000
# alpha: (goal 0.191  tensor([0.1879], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  325000
#
# Epoch  326000
#
# Epoch  327000
#
# Epoch  328000
#
# Saving model... Loss is:  tensor(0.4779, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  328000
# alpha: (goal 0.191  tensor([0.1881], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  329000
#
# Epoch  330000
#
# Epoch  331000
#
# Epoch  332000
#
# Saving model... Loss is:  tensor(0.4778, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  332000
# alpha: (goal 0.191  tensor([0.1882], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  333000
#
# Epoch  334000
#
# Epoch  335000
#
# Epoch  336000
#
# Saving model... Loss is:  tensor(0.4776, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  336000
# alpha: (goal 0.191  tensor([0.1884], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  337000
#
# Epoch  338000
#
# Epoch  339000
#
# Epoch  340000
#
# Saving model... Loss is:  tensor(0.4774, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  340000
# alpha: (goal 0.191  tensor([0.1886], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  341000
#
# Epoch  342000
#
# Epoch  343000
#
# Epoch  344000
#
# Saving model... Loss is:  tensor(0.4773, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  344000
# alpha: (goal 0.191  tensor([0.1887], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  345000
#
# Epoch  346000
#
# Epoch  347000
#
# Epoch  348000
#
# Saving model... Loss is:  tensor(0.4771, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  348000
# alpha: (goal 0.191  tensor([0.1889], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  349000
#
# Epoch  350000
#
# Epoch  351000
#
# Epoch  352000
#
# Saving model... Loss is:  tensor(0.4770, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  352000
# alpha: (goal 0.191  tensor([0.1891], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  353000
#
# Epoch  354000
#
# Epoch  355000
#
# Epoch  356000
#
# Saving model... Loss is:  tensor(0.4768, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  356000
# alpha: (goal 0.191  tensor([0.1893], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  357000
#
# Epoch  358000
#
# Epoch  359000
#
# Epoch  360000
#
# Saving model... Loss is:  tensor(0.4766, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  360000
# alpha: (goal 0.191  tensor([0.1894], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  361000
#
# Epoch  362000
#
# Epoch  363000
#
# Epoch  364000
#
# Saving model... Loss is:  tensor(0.4765, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  364000
# alpha: (goal 0.191  tensor([0.1896], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  365000
#
# Epoch  366000
#
# Epoch  367000
#
# Epoch  368000
#
# Saving model... Loss is:  tensor(0.4763, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  368000
# alpha: (goal 0.191  tensor([0.1898], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  369000
#
# Epoch  370000
#
# Epoch  371000
#
# Epoch  372000
#
# Saving model... Loss is:  tensor(0.4762, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  372000
# alpha: (goal 0.191  tensor([0.1899], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  373000
#
# Epoch  374000
#
# Epoch  375000
#
# Epoch  376000
#
# Saving model... Loss is:  tensor(0.4760, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  376000
# alpha: (goal 0.191  tensor([0.1901], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  377000
#
# Epoch  378000
#
# Epoch  379000
#
# Epoch  380000
#
# Saving model... Loss is:  tensor(0.4758, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  380000
# alpha: (goal 0.191  tensor([0.1903], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  381000
#
# Epoch  382000
#
# Epoch  383000
#
# Epoch  384000
#
# Saving model... Loss is:  tensor(0.4757, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  384000
# alpha: (goal 0.191  tensor([0.1905], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  385000
#
# Epoch  386000
#
# Epoch  387000
#
# Epoch  388000
#
# Saving model... Loss is:  tensor(0.4755, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  388000
# alpha: (goal 0.191  tensor([0.1906], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  389000
#
# Epoch  390000
#
# Epoch  391000
#
# Epoch  392000
#
# Saving model... Loss is:  tensor(0.4753, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  392000
# alpha: (goal 0.191  tensor([0.1908], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  393000
#
# Epoch  394000
#
# Epoch  395000
#
# Epoch  396000
#
# Saving model... Loss is:  tensor(0.4752, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  396000
# alpha: (goal 0.191  tensor([0.1910], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  397000
#
# Epoch  398000
#
# Epoch  399000
#
# Epoch  400000
#
# Saving model... Loss is:  tensor(0.4750, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  400000
# alpha: (goal 0.191  tensor([0.1911], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  401000
#
# Epoch  402000
#
# Epoch  403000
#
# Epoch  404000
#
# Saving model... Loss is:  tensor(0.4749, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  404000
# alpha: (goal 0.191  tensor([0.1913], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  405000
#
# Epoch  406000
#
# Epoch  407000
#
# Epoch  408000
#
# Saving model... Loss is:  tensor(0.4747, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  408000
# alpha: (goal 0.191  tensor([0.1915], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  409000
#
# Epoch  410000
#
# Epoch  411000
#
# Epoch  412000
#
# Saving model... Loss is:  tensor(0.4745, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  412000
# alpha: (goal 0.191  tensor([0.1916], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  413000
#
# Epoch  414000
#
# Epoch  415000
#
# Epoch  416000
#
# Saving model... Loss is:  tensor(0.4744, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  416000
# alpha: (goal 0.191  tensor([0.1918], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  417000
#
# Epoch  418000
#
# Epoch  419000
#
# Epoch  420000
#
# Saving model... Loss is:  tensor(0.4742, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  420000
# alpha: (goal 0.191  tensor([0.1920], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  421000
#
# Epoch  422000
#
# Epoch  423000
#
# Epoch  424000
#
# Saving model... Loss is:  tensor(0.4741, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  424000
# alpha: (goal 0.191  tensor([0.1922], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  425000
#
# Epoch  426000
#
# Epoch  427000
#
# Epoch  428000
#
# Saving model... Loss is:  tensor(0.4739, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  428000
# alpha: (goal 0.191  tensor([0.1923], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  429000
#
# Epoch  430000
#
# Epoch  431000
#
# Epoch  432000
#
# Saving model... Loss is:  tensor(0.4737, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  432000
# alpha: (goal 0.191  tensor([0.1925], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  433000
#
# Epoch  434000
#
# Epoch  435000
#
# Epoch  436000
#
# Saving model... Loss is:  tensor(0.4736, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  436000
# alpha: (goal 0.191  tensor([0.1927], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  437000
#
# Epoch  438000
#
# Epoch  439000
#
# Epoch  440000
#
# Saving model... Loss is:  tensor(0.4734, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  440000
# alpha: (goal 0.191  tensor([0.1928], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  441000
#
# Epoch  442000
#
# Epoch  443000
#
# Epoch  444000
#
# Saving model... Loss is:  tensor(0.4732, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  444000
# alpha: (goal 0.191  tensor([0.1930], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  445000
#
# Epoch  446000
#
# Epoch  447000
#
# Epoch  448000
#
# Saving model... Loss is:  tensor(0.4731, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  448000
# alpha: (goal 0.191  tensor([0.1932], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  449000
#
# Epoch  450000
#
# Epoch  451000
#
# Epoch  452000
#
# Saving model... Loss is:  tensor(0.4729, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  452000
# alpha: (goal 0.191  tensor([0.1933], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  453000
#
# Epoch  454000
#
# Epoch  455000
#
# Epoch  456000
#
# Saving model... Loss is:  tensor(0.4728, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  456000
# alpha: (goal 0.191  tensor([0.1935], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  457000
#
# Epoch  458000
#
# Epoch  459000
#
# Epoch  460000
#
# Saving model... Loss is:  tensor(0.4726, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  460000
# alpha: (goal 0.191  tensor([0.1937], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  461000
#
# Epoch  462000
#
# Epoch  463000
#
# Epoch  464000
#
# Saving model... Loss is:  tensor(0.4724, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  464000
# alpha: (goal 0.191  tensor([0.1939], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  465000
#
# Epoch  466000
#
# Epoch  467000
#
# Epoch  468000
#
# Saving model... Loss is:  tensor(0.4723, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  468000
# alpha: (goal 0.191  tensor([0.1940], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  469000
#
# Epoch  470000
#
# Epoch  471000
#
# Epoch  472000
#
# Saving model... Loss is:  tensor(0.4721, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  472000
# alpha: (goal 0.191  tensor([0.1942], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  473000
#
# Epoch  474000
#
# Epoch  475000
#
# Epoch  476000
#
# Saving model... Loss is:  tensor(0.4720, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  476000
# alpha: (goal 0.191  tensor([0.1944], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  477000
#
# Epoch  478000
#
# Epoch  479000
#
# Epoch  480000
#
# Saving model... Loss is:  tensor(0.4718, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  480000
# alpha: (goal 0.191  tensor([0.1945], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  481000
#
# Epoch  482000
#
# Epoch  483000
#
# Epoch  484000
#
# Saving model... Loss is:  tensor(0.4716, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  484000
# alpha: (goal 0.191  tensor([0.1947], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  485000
#
# Epoch  486000
#
# Epoch  487000
#
# Epoch  488000
#
# Saving model... Loss is:  tensor(0.4715, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  488000
# alpha: (goal 0.191  tensor([0.1949], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  489000
#
# Epoch  490000
#
# Epoch  491000
#
# Epoch  492000
#
# Saving model... Loss is:  tensor(0.4713, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  492000
# alpha: (goal 0.191  tensor([0.1951], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  493000
#
# Epoch  494000
#
# Epoch  495000
#
# Epoch  496000
#
# Saving model... Loss is:  tensor(0.4712, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  496000
# alpha: (goal 0.191  tensor([0.1952], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  497000
#
# Epoch  498000
#
# Epoch  499000
#
# Epoch  500000
#
# Saving model... Loss is:  tensor(0.4710, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  500000
# alpha: (goal 0.191  tensor([0.1954], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  501000
#
# Epoch  502000
#
# Epoch  503000
#
# Epoch  504000
#
# Saving model... Loss is:  tensor(0.4708, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  504000
# alpha: (goal 0.191  tensor([0.1956], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  505000
#
# Epoch  506000
#
# Epoch  507000
#
# Epoch  508000
#
# Saving model... Loss is:  tensor(0.4707, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  508000
# alpha: (goal 0.191  tensor([0.1957], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  509000
#
# Epoch  510000
#
# Epoch  511000
#
# Epoch  512000
#
# Saving model... Loss is:  tensor(0.4705, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  512000
# alpha: (goal 0.191  tensor([0.1959], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  513000
#
# Epoch  514000
#
# Epoch  515000
#
# Epoch  516000
#
# Saving model... Loss is:  tensor(0.4703, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  516000
# alpha: (goal 0.191  tensor([0.1961], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  517000
#
# Epoch  518000
#
# Epoch  519000
#
# Epoch  520000
#
# Saving model... Loss is:  tensor(0.4702, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  520000
# alpha: (goal 0.191  tensor([0.1962], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  521000
#
# Epoch  522000
#
# Epoch  523000
#
# Epoch  524000
#
# Saving model... Loss is:  tensor(0.4700, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  524000
# alpha: (goal 0.191  tensor([0.1964], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  525000
#
# Epoch  526000
#
# Epoch  527000
#
# Epoch  528000
#
# Saving model... Loss is:  tensor(0.4699, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  528000
# alpha: (goal 0.191  tensor([0.1966], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  529000
#
# Epoch  530000
#
# Epoch  531000
#
# Epoch  532000
#
# Saving model... Loss is:  tensor(0.4697, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  532000
# alpha: (goal 0.191  tensor([0.1968], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  533000
#
# Epoch  534000
#
# Epoch  535000
#
# Epoch  536000
#
# Saving model... Loss is:  tensor(0.4695, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  536000
# alpha: (goal 0.191  tensor([0.1969], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  537000
#
# Epoch  538000
#
# Epoch  539000
#
# Epoch  540000
#
# Saving model... Loss is:  tensor(0.4694, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  540000
# alpha: (goal 0.191  tensor([0.1971], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  541000
#
# Epoch  542000
#
# Epoch  543000
#
# Epoch  544000
#
# Saving model... Loss is:  tensor(0.4692, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  544000
# alpha: (goal 0.191  tensor([0.1973], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  545000
#
# Epoch  546000
#
# Epoch  547000
#
# Epoch  548000
#
# Saving model... Loss is:  tensor(0.4691, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  548000
# alpha: (goal 0.191  tensor([0.1974], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  549000
#
# Epoch  550000
#
# Epoch  551000
#
# Epoch  552000
#
# Saving model... Loss is:  tensor(0.4689, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  552000
# alpha: (goal 0.191  tensor([0.1976], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  553000
#
# Epoch  554000
#
# Epoch  555000
#
# Epoch  556000
#
# Saving model... Loss is:  tensor(0.4687, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  556000
# alpha: (goal 0.191  tensor([0.1978], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# ...
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1217000
#
# Epoch  1218000
#
# Epoch  1219000
#
# Epoch  1220000
#
# Saving model... Loss is:  tensor(0.4395, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1220000
# alpha: (goal 0.191  tensor([0.2260], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1221000
#
# Epoch  1222000
#
# Epoch  1223000
#
# Epoch  1224000
#
# Saving model... Loss is:  tensor(0.4393, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1224000
# alpha: (goal 0.191  tensor([0.2262], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1225000
#
# Epoch  1226000
#
# Epoch  1227000
#
# Epoch  1228000
#
# Saving model... Loss is:  tensor(0.4392, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1228000
# alpha: (goal 0.191  tensor([0.2264], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1229000
#
# Epoch  1230000
#
# Epoch  1231000
#
# Epoch  1232000
#
# Saving model... Loss is:  tensor(0.4390, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1232000
# alpha: (goal 0.191  tensor([0.2265], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1233000
#
# Epoch  1234000
#
# Epoch  1235000
#
# Epoch  1236000
#
# Saving model... Loss is:  tensor(0.4388, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1236000
# alpha: (goal 0.191  tensor([0.2267], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1237000
#
# Epoch  1238000
#
# Epoch  1239000
#
# Epoch  1240000
#
# Saving model... Loss is:  tensor(0.4386, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1240000
# alpha: (goal 0.191  tensor([0.2269], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1241000
#
# Epoch  1242000
#
# Epoch  1243000
#
# Epoch  1244000
#
# Saving model... Loss is:  tensor(0.4385, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1244000
# alpha: (goal 0.191  tensor([0.2271], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1245000
#
# Epoch  1246000
#
# Epoch  1247000
#
# Epoch  1248000
#
# Saving model... Loss is:  tensor(0.4383, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1248000
# alpha: (goal 0.191  tensor([0.2272], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1249000
#
# Epoch  1250000
#
# Epoch  1251000
#
# Epoch  1252000
#
# Saving model... Loss is:  tensor(0.4381, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1252000
# alpha: (goal 0.191  tensor([0.2274], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1253000
#
# Epoch  1254000
#
# Epoch  1255000
#
# Epoch  1256000
#
# Saving model... Loss is:  tensor(0.4379, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1256000
# alpha: (goal 0.191  tensor([0.2276], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1257000
#
# Epoch  1258000
#
# Epoch  1259000
#
# Epoch  1260000
#
# Saving model... Loss is:  tensor(0.4377, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1260000
# alpha: (goal 0.191  tensor([0.2277], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1261000
#
# Epoch  1262000
#
# Epoch  1263000
#
# Epoch  1264000
#
# Saving model... Loss is:  tensor(0.4376, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1264000
# alpha: (goal 0.191  tensor([0.2279], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1265000
#
# Epoch  1266000
#
# Epoch  1267000
#
# Epoch  1268000
#
# Saving model... Loss is:  tensor(0.4374, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1268000
# alpha: (goal 0.191  tensor([0.2281], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1269000
#
# Epoch  1270000
#
# Epoch  1271000
#
# Epoch  1272000
#
# Saving model... Loss is:  tensor(0.4372, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1272000
# alpha: (goal 0.191  tensor([0.2282], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1273000
#
# Epoch  1274000
#
# Epoch  1275000
#
# Epoch  1276000
#
# Saving model... Loss is:  tensor(0.4370, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1276000
# alpha: (goal 0.191  tensor([0.2284], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1277000
#
# Epoch  1278000
#
# Epoch  1279000
#
# Epoch  1280000
#
# Saving model... Loss is:  tensor(0.4369, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1280000
# alpha: (goal 0.191  tensor([0.2286], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1281000
#
# Epoch  1282000
#
# Epoch  1283000
#
# Epoch  1284000
#
# Saving model... Loss is:  tensor(0.4367, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1284000
# alpha: (goal 0.191  tensor([0.2288], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1285000
#
# Epoch  1286000
#
# Epoch  1287000
#
# Epoch  1288000
#
# Saving model... Loss is:  tensor(0.4365, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1288000
# alpha: (goal 0.191  tensor([0.2289], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1289000
#
# Epoch  1290000
#
# Epoch  1291000
#
# Epoch  1292000
#
# Saving model... Loss is:  tensor(0.4363, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1292000
# alpha: (goal 0.191  tensor([0.2291], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1293000
#
# Epoch  1294000
#
# Epoch  1295000
#
# Epoch  1296000
#
# Saving model... Loss is:  tensor(0.4362, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1296000
# alpha: (goal 0.191  tensor([0.2293], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1297000
#
# Epoch  1298000
#
# Epoch  1299000
#
# Epoch  1300000
#
# Saving model... Loss is:  tensor(0.4360, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1300000
# alpha: (goal 0.191  tensor([0.2294], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1301000
#
# Epoch  1302000
#
# Epoch  1303000
#
# Epoch  1304000
#
# Saving model... Loss is:  tensor(0.4358, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1304000
# alpha: (goal 0.191  tensor([0.2296], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1305000
#
# Epoch  1306000
#
# Epoch  1307000
#
# Epoch  1308000
#
# Saving model... Loss is:  tensor(0.4356, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1308000
# alpha: (goal 0.191  tensor([0.2298], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1309000
#
# Epoch  1310000
#
# Epoch  1311000
#
# Epoch  1312000
#
# Saving model... Loss is:  tensor(0.4355, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1312000
# alpha: (goal 0.191  tensor([0.2299], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1313000
#
# Epoch  1314000
#
# Epoch  1315000
#
# Epoch  1316000
#
# Saving model... Loss is:  tensor(0.4353, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1316000
# alpha: (goal 0.191  tensor([0.2301], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1317000
#
# Epoch  1318000
#
# Epoch  1319000
#
# Epoch  1320000
#
# Saving model... Loss is:  tensor(0.4351, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1320000
# alpha: (goal 0.191  tensor([0.2303], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1321000
#
# Epoch  1322000
#
# Epoch  1323000
#
# Epoch  1324000
#
# Saving model... Loss is:  tensor(0.4349, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1324000
# alpha: (goal 0.191  tensor([0.2305], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1325000
#
# Epoch  1326000
#
# Epoch  1327000
#
# Epoch  1328000
#
# Saving model... Loss is:  tensor(0.4348, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1328000
# alpha: (goal 0.191  tensor([0.2306], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1329000
#
# Epoch  1330000
#
# Epoch  1331000
#
# Epoch  1332000
#
# Saving model... Loss is:  tensor(0.4346, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1332000
# alpha: (goal 0.191  tensor([0.2308], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1333000
#
# Epoch  1334000
#
# Epoch  1335000
#
# Epoch  1336000
#
# Saving model... Loss is:  tensor(0.4344, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1336000
# alpha: (goal 0.191  tensor([0.2310], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1337000
#
# Epoch  1338000
#
# Epoch  1339000
#
# Epoch  1340000
#
# Saving model... Loss is:  tensor(0.4342, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1340000
# alpha: (goal 0.191  tensor([0.2311], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1341000
#
# Epoch  1342000
#
# Epoch  1343000
#
# Epoch  1344000
#
# Saving model... Loss is:  tensor(0.4341, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1344000
# alpha: (goal 0.191  tensor([0.2313], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1345000
#
# Epoch  1346000
#
# Epoch  1347000
#
# Epoch  1348000
#
# Saving model... Loss is:  tensor(0.4339, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1348000
# alpha: (goal 0.191  tensor([0.2315], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1349000
#
# Epoch  1350000
#
# Epoch  1351000
#
# Epoch  1352000
#
# Saving model... Loss is:  tensor(0.4337, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1352000
# alpha: (goal 0.191  tensor([0.2317], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1353000
#
# Epoch  1354000
#
# Epoch  1355000
#
# Epoch  1356000
#
# Saving model... Loss is:  tensor(0.4335, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1356000
# alpha: (goal 0.191  tensor([0.2318], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1357000
#
# Epoch  1358000
#
# Epoch  1359000
#
# Epoch  1360000
#
# Saving model... Loss is:  tensor(0.4334, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1360000
# alpha: (goal 0.191  tensor([0.2320], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1361000
#
# Epoch  1362000
#
# Epoch  1363000
#
# Epoch  1364000
#
# Saving model... Loss is:  tensor(0.4332, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1364000
# alpha: (goal 0.191  tensor([0.2322], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1365000
#
# Epoch  1366000
#
# Epoch  1367000
#
# Epoch  1368000
#
# Saving model... Loss is:  tensor(0.4330, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1368000
# alpha: (goal 0.191  tensor([0.2323], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1369000
#
# Epoch  1370000
#
# Epoch  1371000
#
# Epoch  1372000
#
# Saving model... Loss is:  tensor(0.4328, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1372000
# alpha: (goal 0.191  tensor([0.2325], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1373000
#
# Epoch  1374000
#
# Epoch  1375000
#
# Epoch  1376000
#
# Saving model... Loss is:  tensor(0.4327, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1376000
# alpha: (goal 0.191  tensor([0.2327], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1377000
#
# Epoch  1378000
#
# Epoch  1379000
#
# Epoch  1380000
#
# Saving model... Loss is:  tensor(0.4325, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1380000
# alpha: (goal 0.191  tensor([0.2328], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1381000
#
# Epoch  1382000
#
# Epoch  1383000
#
# Epoch  1384000
#
# Saving model... Loss is:  tensor(0.4323, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1384000
# alpha: (goal 0.191  tensor([0.2330], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1385000
#
# Epoch  1386000
#
# Epoch  1387000
#
# Epoch  1388000
#
# Saving model... Loss is:  tensor(0.4321, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1388000
# alpha: (goal 0.191  tensor([0.2332], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1389000
#
# Epoch  1390000
#
# Epoch  1391000
#
# Epoch  1392000
#
# Saving model... Loss is:  tensor(0.4320, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1392000
# alpha: (goal 0.191  tensor([0.2334], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1393000
#
# Epoch  1394000
#
# Epoch  1395000
#
# Epoch  1396000
#
# Saving model... Loss is:  tensor(0.4318, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  1396000
# alpha: (goal 0.191  tensor([0.2335], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1397000
#
# Epoch  1398000
#
# Epoch  1399000
# CPU times: user 1h 25min 1s, sys: 20 s, total: 1h 25min 22s
# Wall time: 1h 25min 39s

# %%
plt.plot(dinn.losses[0:], color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss'),
# Out:
# (Text(0, 0.5, 'Loss'),)

# %%
fig = plt.figure(figsize=(12,12))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')


ax.plot(sidr_data[0], sidr_data[1], 'pink', alpha=0.5, lw=2, label='Susceptible')
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax.plot(sidr_data[0], sidr_data[2], 'violet', alpha=0.5, lw=2, label='Infected')
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax.plot(sidr_data[0], sidr_data[3], 'darkgreen', alpha=0.5, lw=2, label='Dead')
ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax.plot(sidr_data[0], sidr_data[4], 'blue', alpha=0.5, lw=2, label='Recovered')
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
#ax.set_ylim([-1,50])
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='black', lw=0.2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('itswhite.pdf')
plt.show()

# %%
#calculate relative MSE loss
import math
import numpy as np

S_total_loss = 0
S_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0
t = np.linspace(0, 500, 100) 

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S_pred_list[0].detach().numpy()[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2
  I_value = sidr_data[2][timestep] - I_pred_list[0].detach().numpy()[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[2][timestep])**2
  D_value = sidr_data[3][timestep] - D_pred_list[0].detach().numpy()[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[3][timestep])**2
  R_value = sidr_data[4][timestep] - R_pred_list[0].detach().numpy()[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[4][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S_total_loss: ', S_total_loss)
print('I_total_loss: ', I_total_loss)
print('D_total_loss: ', D_total_loss)
print('R_total_loss: ', R_total_loss)
# Out:
# S_total_loss:  0.8242531866018197
# I_total_loss:  0.9669729835165153
# D_total_loss:  0.27898212231311936
# R_total_loss:  0.27315554072771114

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial conditions
N = 59e6

S0 = N - 1
I0 = 1
D0 = 0
R0 = 0
# A grid of time points (in days)
t = np.linspace(0, 500, 100) 

#parameters
alpha = dinn.alpha
beta = dinn.beta
gamma = dinn.gamma

# The SIR model differential equations.
def deriv(y, t, alpha, betta, gamma):
    S, I, D, R = y
    dSdt = - (alpha / N) * S * I
    dIdt = (alpha / N) * S * I - beta * I - gamma * I 
    dDdt = gamma * I
    dRdt = beta * I

    return dSdt, dIdt, dDdt, dRdt


# Initial conditions vector
y0 = S0, I0, D0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(alpha, beta, gamma))
S, I, D, R = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(t, sidr_data[1], 'dodgerblue', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, I, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.plot(t, sidr_data[2], 'gold', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, D, 'red', alpha=0.5, lw=2, label='Learnable Param Dead', linestyle='dashed')
ax.plot(t, sidr_data[3], 'salmon', alpha=0.5, lw=2, label='Dead')

ax.plot(t, R, 'blue', alpha=0.5, lw=2, label='Learnable Param Recovered', linestyle='dashed')
ax.plot(t, sidr_data[4], 'wheat', alpha=0.5, lw=2, label='Recovered')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#calculate relative MSE loss
import math

S_total_loss = 0
S_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2
  I_value = sidr_data[2][timestep] - I[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[2][timestep])**2
  D_value = sidr_data[3][timestep] - D[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[3][timestep])**2
  R_value = sidr_data[4][timestep] - R[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[4][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S_total_loss: ', S_total_loss)
print('I_total_loss: ', I_total_loss)
print('D_total_loss: ', D_total_loss)
print('R_total_loss: ', R_total_loss)
# Out:
# S_total_loss:  1.2835644495423215
# I_total_loss:  0.999999999999999
# D_total_loss:  0.9999999727630735
# R_total_loss:  0.999999959107108
