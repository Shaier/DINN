# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('covid_100_pts.csv', delimiter=',') #in the form of [t,S,I,D,R]

torch.manual_seed(1234)

# %%
# %%time

PATH = 'covid_lr6_step_1000_' 

class DINN(nn.Module):
    def __init__(self, t, S_data, I_data, D_data, R_data): #[t,S,I,D,R]
        super(DINN, self).__init__()
        self.N = 59e6 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.I = torch.tensor(I_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 3 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True)) #0.191
        self.beta_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True)) #0.05
        self.gamma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True)) #0.0294
        
        #find values for normalization
        self.S_max = max(self.S)
        self.I_max = max(self.I)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.I_min = min(self.I)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #unnormalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x4 for S,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 4)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 4)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 4)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 4)); self.m4[:, 3] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda, self.gamma_tilda]))

    #force parameters to be in a range
    @property
    def alpha(self):
        return torch.tanh(self.alpha_tilda)*0.191*20

    @property
    def beta(self):
        return torch.tanh(self.beta_tilda)*0.05*20
    
    @property
    def gamma(self):
        return torch.tanh(self.gamma_tilda)*0.0294*20


    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)      
            self.out=nn.Linear(20, 4) #outputs S, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, I_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m2, retain_graph=True)
        
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m3, retain_graph=True)
        
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m4, retain_graph=True)
        
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-(self.alpha / self.N) * S * I)  / (self.S_max - self.S_min)
        f2_hat = I_hat_t - ((self.alpha / self.N) * S * I - self.beta * I - self.gamma * I ) / (self.I_max - self.I_min)
        f3_hat = D_hat_t - (self.gamma * I) / (self.D_max - self.D_min)
        f4_hat = R_hat_t - (self.beta * I ) / (self.R_max - self.R_min)


        return f1_hat, f2_hat, f3_hat, f4_hat, S_hat, I_hat, D_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
         
        self.losses = checkpoint['losses']
         
         

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        I_pred_list = []
        D_pred_list = []
        R_pred_list = []

         
        f1, f2, f3, f4, S_pred, I_pred, D_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        loss = (torch.mean(torch.square(self.S_hat - S_pred))+ 
                torch.mean(torch.square(self.I_hat - I_pred))+
                torch.mean(torch.square(self.D_hat - D_pred))+
                torch.mean(torch.square(self.R_hat - R_pred))+
                torch.mean(torch.square(f1))+
                torch.mean(torch.square(f2))+
                torch.mean(torch.square(f3))+
                torch.mean(torch.square(f4))
                ) 

         
        loss.backward()
        self.optimizer.step()
        self.scheduler.step() 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)

        #loss + model parameters update
        if epoch % 4000 == 0:
          #checkpoint save every 100 epochs if the loss is lower
          print('\nSaving model... Loss is: ', loss)
          torch.save({
              'epoch': epoch,
              'model': self.state_dict(),
              'optimizer_state_dict': self.optimizer.state_dict(),
              'scheduler': self.scheduler.state_dict(),
              #'loss': loss,
              'losses': self.losses,
              }, PATH + str(self.save)+'.pt')
          if self.save % 2 > 0: #its on 3
            self.save = 2 #change to 2
          else: #its on 2
            self.save = 3 #change to 3

          print('epoch: ', epoch)
          print('alpha: (goal 0.191 ', self.alpha)
          print('beta: (goal 0.05 ', self.beta)
          print('gamma: (goal 0.0294 ', self.gamma)

          if loss < 4e-4:
            break

      return S_pred_list, I_pred_list, D_pred_list, R_pred_list
# Out:
# CPU times: user 49 µs, sys: 11 µs, total: 60 µs
# Wall time: 63.4 µs

# %%
# %%time

 
dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[3], 
            sidr_data[4]) #in the form of [t,S,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

 
scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)

dinn.scheduler = scheduler

try: 
  S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(700000) #train
except EOFError:
  if dinn.save == 2:
    dinn.save = 3
    S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(700000) #train
  elif dinn.save == 3:
    dinn.save = 2
    S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(700000) #train
# Out:
# starting training...
#
#
# Epoch  0
#
# Saving model... Loss is:  tensor(13.6777, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  0
# alpha: (goal 0.191  tensor([0.1107], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3816], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1494], grad_fn=<MulBackward0>)
#
# Epoch  1000
#
# Epoch  2000
#
# Epoch  3000
#
# Epoch  4000
#
# Saving model... Loss is:  tensor(5.7514, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  4000
# alpha: (goal 0.191  tensor([0.1254], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3786], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1475], grad_fn=<MulBackward0>)
#
# Epoch  5000
#
# Epoch  6000
#
# Epoch  7000
#
# Epoch  8000
#
# Saving model... Loss is:  tensor(2.4285, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  8000
# alpha: (goal 0.191  tensor([0.1335], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3768], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1464], grad_fn=<MulBackward0>)
#
# Epoch  9000
#
# Epoch  10000
#
# Epoch  11000
#
# Epoch  12000
#
# Saving model... Loss is:  tensor(1.0806, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  12000
# alpha: (goal 0.191  tensor([0.1381], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3754], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1455], grad_fn=<MulBackward0>)
#
# Epoch  13000
#
# Epoch  14000
#
# Epoch  15000
#
# Epoch  16000
#
# Saving model... Loss is:  tensor(0.6319, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  16000
# alpha: (goal 0.191  tensor([0.1485], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3723], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1435], grad_fn=<MulBackward0>)
#
# Epoch  17000
#
# Epoch  18000
#
# Epoch  19000
#
# Epoch  20000
#
# Saving model... Loss is:  tensor(0.4977, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  20000
# alpha: (goal 0.191  tensor([0.1611], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3689], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1414], grad_fn=<MulBackward0>)
#
# Epoch  21000
#
# Epoch  22000
#
# Epoch  23000
#
# Epoch  24000
#
# Saving model... Loss is:  tensor(0.4713, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  24000
# alpha: (goal 0.191  tensor([0.1739], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3655], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1392], grad_fn=<MulBackward0>)
#
# Epoch  25000
#
# Epoch  26000
#
# Epoch  27000
#
# Epoch  28000
#
# Saving model... Loss is:  tensor(0.4584, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  28000
# alpha: (goal 0.191  tensor([0.1884], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3621], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1370], grad_fn=<MulBackward0>)
#
# Epoch  29000
#
# Epoch  30000
#
# Epoch  31000
#
# Epoch  32000
#
# Saving model... Loss is:  tensor(0.4424, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  32000
# alpha: (goal 0.191  tensor([0.2034], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3587], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1348], grad_fn=<MulBackward0>)
#
# Epoch  33000
#
# Epoch  34000
#
# Epoch  35000
#
# Epoch  36000
#
# Saving model... Loss is:  tensor(0.4263, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  36000
# alpha: (goal 0.191  tensor([0.2186], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3552], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1326], grad_fn=<MulBackward0>)
#
# Epoch  37000
#
# Epoch  38000
#
# Epoch  39000
#
# Epoch  40000
#
# Saving model... Loss is:  tensor(0.4097, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  40000
# alpha: (goal 0.191  tensor([0.2339], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3517], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1303], grad_fn=<MulBackward0>)
#
# Epoch  41000
#
# Epoch  42000
#
# Epoch  43000
#
# Epoch  44000
#
# Saving model... Loss is:  tensor(0.3880, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  44000
# alpha: (goal 0.191  tensor([0.2498], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3480], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1279], grad_fn=<MulBackward0>)
#
# Epoch  45000
#
# Epoch  46000
#
# Epoch  47000
#
# Epoch  48000
#
# Saving model... Loss is:  tensor(0.3643, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  48000
# alpha: (goal 0.191  tensor([0.2662], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3443], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1256], grad_fn=<MulBackward0>)
#
# Epoch  49000
#
# Epoch  50000
#
# Epoch  51000
#
# Epoch  52000
#
# Saving model... Loss is:  tensor(0.3448, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  52000
# alpha: (goal 0.191  tensor([0.2826], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3406], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1232], grad_fn=<MulBackward0>)
#
# Epoch  53000
#
# Epoch  54000
#
# Epoch  55000
#
# Epoch  56000
#
# Saving model... Loss is:  tensor(0.3249, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  56000
# alpha: (goal 0.191  tensor([0.2989], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3369], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1208], grad_fn=<MulBackward0>)
#
# Epoch  57000
#
# Epoch  58000
#
# Epoch  59000
#
# Epoch  60000
#
# Saving model... Loss is:  tensor(0.3032, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  60000
# alpha: (goal 0.191  tensor([0.3151], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3332], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1185], grad_fn=<MulBackward0>)
#
# Epoch  61000
#
# Epoch  62000
#
# Epoch  63000
#
# Epoch  64000
#
# Saving model... Loss is:  tensor(0.2829, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  64000
# alpha: (goal 0.191  tensor([0.3310], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3296], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1162], grad_fn=<MulBackward0>)
#
# Epoch  65000
#
# Epoch  66000
#
# Epoch  67000
#
# Epoch  68000
#
# Saving model... Loss is:  tensor(0.2621, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  68000
# alpha: (goal 0.191  tensor([0.3464], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3260], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1139], grad_fn=<MulBackward0>)
#
# Epoch  69000
#
# Epoch  70000
#
# Epoch  71000
#
# Epoch  72000
#
# Saving model... Loss is:  tensor(0.2346, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  72000
# alpha: (goal 0.191  tensor([0.3614], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3225], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1117], grad_fn=<MulBackward0>)
#
# Epoch  73000
#
# Epoch  74000
#
# Epoch  75000
#
# Epoch  76000
#
# Saving model... Loss is:  tensor(0.2087, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  76000
# alpha: (goal 0.191  tensor([0.3767], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3190], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1094], grad_fn=<MulBackward0>)
#
# Epoch  77000
#
# Epoch  78000
#
# Epoch  79000
#
# Epoch  80000
#
# Saving model... Loss is:  tensor(0.1919, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  80000
# alpha: (goal 0.191  tensor([0.3915], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3154], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1072], grad_fn=<MulBackward0>)
#
# Epoch  81000
#
# Epoch  82000
#
# Epoch  83000
#
# Epoch  84000
#
# Saving model... Loss is:  tensor(0.1768, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  84000
# alpha: (goal 0.191  tensor([0.4060], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3120], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1050], grad_fn=<MulBackward0>)
#
# Epoch  85000
#
# Epoch  86000
#
# Epoch  87000
#
# Epoch  88000
#
# Saving model... Loss is:  tensor(0.1642, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  88000
# alpha: (goal 0.191  tensor([0.4200], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3085], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1029], grad_fn=<MulBackward0>)
#
# Epoch  89000
#
# Epoch  90000
#
# Epoch  91000
#
# Epoch  92000
#
# Saving model... Loss is:  tensor(0.1533, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  92000
# alpha: (goal 0.191  tensor([0.4334], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3051], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.1007], grad_fn=<MulBackward0>)
#
# Epoch  93000
#
# Epoch  94000
#
# Epoch  95000
#
# Epoch  96000
#
# Saving model... Loss is:  tensor(0.1458, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  96000
# alpha: (goal 0.191  tensor([0.4451], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.3016], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0986], grad_fn=<MulBackward0>)
#
# Epoch  97000
#
# Epoch  98000
#
# Epoch  99000
#
# Epoch  100000
#
# Saving model... Loss is:  tensor(0.1401, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  100000
# alpha: (goal 0.191  tensor([0.4497], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2982], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0964], grad_fn=<MulBackward0>)
#
# Epoch  101000
#
# Epoch  102000
#
# Epoch  103000
#
# Epoch  104000
#
# Saving model... Loss is:  tensor(0.1345, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  104000
# alpha: (goal 0.191  tensor([0.4449], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2945], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0941], grad_fn=<MulBackward0>)
#
# Epoch  105000
#
# Epoch  106000
#
# Epoch  107000
#
# Epoch  108000
#
# Saving model... Loss is:  tensor(0.1263, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  108000
# alpha: (goal 0.191  tensor([0.4655], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2909], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0919], grad_fn=<MulBackward0>)
#
# Epoch  109000
#
# Epoch  110000
#
# Epoch  111000
#
# Epoch  112000
#
# Saving model... Loss is:  tensor(0.1213, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  112000
# alpha: (goal 0.191  tensor([0.4647], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2873], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0896], grad_fn=<MulBackward0>)
#
# Epoch  113000
#
# Epoch  114000
#
# Epoch  115000
#
# Epoch  116000
#
# Saving model... Loss is:  tensor(0.1162, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  116000
# alpha: (goal 0.191  tensor([0.4526], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2835], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0873], grad_fn=<MulBackward0>)
#
# Epoch  117000
#
# Epoch  118000
#
# Epoch  119000
#
# Epoch  120000
#
# Saving model... Loss is:  tensor(0.1110, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  120000
# alpha: (goal 0.191  tensor([0.4444], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2798], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0849], grad_fn=<MulBackward0>)
#
# Epoch  121000
#
# Epoch  122000
#
# Epoch  123000
#
# Epoch  124000
#
# Saving model... Loss is:  tensor(0.1054, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  124000
# alpha: (goal 0.191  tensor([0.4399], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2761], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0826], grad_fn=<MulBackward0>)
#
# Epoch  125000
#
# Epoch  126000
#
# Epoch  127000
#
# Epoch  128000
#
# Saving model... Loss is:  tensor(0.0997, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  128000
# alpha: (goal 0.191  tensor([0.4356], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2723], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0803], grad_fn=<MulBackward0>)
#
# Epoch  129000
#
# Epoch  130000
#
# Epoch  131000
#
# Epoch  132000
#
# Saving model... Loss is:  tensor(0.0939, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  132000
# alpha: (goal 0.191  tensor([0.4327], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2686], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0779], grad_fn=<MulBackward0>)
#
# Epoch  133000
#
# Epoch  134000
#
# Epoch  135000
#
# Epoch  136000
#
# Saving model... Loss is:  tensor(0.0877, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  136000
# alpha: (goal 0.191  tensor([0.4318], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2648], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0756], grad_fn=<MulBackward0>)
#
# Epoch  137000
#
# Epoch  138000
#
# Epoch  139000
#
# Epoch  140000
#
# Saving model... Loss is:  tensor(0.0818, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  140000
# alpha: (goal 0.191  tensor([0.4295], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2610], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0732], grad_fn=<MulBackward0>)
#
# Epoch  141000
#
# Epoch  142000
#
# Epoch  143000
#
# Epoch  144000
#
# Saving model... Loss is:  tensor(0.0761, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  144000
# alpha: (goal 0.191  tensor([0.4270], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2572], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0709], grad_fn=<MulBackward0>)
#
# Epoch  145000
#
# Epoch  146000
#
# Epoch  147000
#
# Epoch  148000
#
# Saving model... Loss is:  tensor(0.0708, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  148000
# alpha: (goal 0.191  tensor([0.4238], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2534], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0685], grad_fn=<MulBackward0>)
#
# Epoch  149000
#
# Epoch  150000
#
# Epoch  151000
#
# Epoch  152000
#
# Saving model... Loss is:  tensor(0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  152000
# alpha: (goal 0.191  tensor([0.4202], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2496], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0662], grad_fn=<MulBackward0>)
#
# Epoch  153000
#
# Epoch  154000
#
# Epoch  155000
#
# Epoch  156000
#
# Saving model... Loss is:  tensor(0.0610, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  156000
# alpha: (goal 0.191  tensor([0.4158], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2458], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0638], grad_fn=<MulBackward0>)
#
# Epoch  157000
#
# Epoch  158000
#
# Epoch  159000
#
# Epoch  160000
#
# Saving model... Loss is:  tensor(0.0566, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  160000
# alpha: (goal 0.191  tensor([0.4113], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2420], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0615], grad_fn=<MulBackward0>)
#
# Epoch  161000
#
# Epoch  162000
#
# Epoch  163000
#
# Epoch  164000
#
# Saving model... Loss is:  tensor(0.0524, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  164000
# alpha: (goal 0.191  tensor([0.4062], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2382], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0591], grad_fn=<MulBackward0>)
#
# Epoch  165000
#
# Epoch  166000
#
# Epoch  167000
#
# Epoch  168000
#
# Saving model... Loss is:  tensor(0.0486, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  168000
# alpha: (goal 0.191  tensor([0.3992], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2344], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0568], grad_fn=<MulBackward0>)
#
# Epoch  169000
#
# Epoch  170000
#
# Epoch  171000
#
# Epoch  172000
#
# Saving model... Loss is:  tensor(0.0450, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  172000
# alpha: (goal 0.191  tensor([0.3908], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2306], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0544], grad_fn=<MulBackward0>)
#
# Epoch  173000
#
# Epoch  174000
#
# Epoch  175000
#
# Epoch  176000
#
# Saving model... Loss is:  tensor(0.0416, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  176000
# alpha: (goal 0.191  tensor([0.3840], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2268], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0521], grad_fn=<MulBackward0>)
#
# Epoch  177000
#
# Epoch  178000
#
# Epoch  179000
#
# Epoch  180000
#
# Saving model... Loss is:  tensor(0.0386, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  180000
# alpha: (goal 0.191  tensor([0.3766], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2230], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0498], grad_fn=<MulBackward0>)
#
# Epoch  181000
#
# Epoch  182000
#
# Epoch  183000
#
# Epoch  184000
#
# Saving model... Loss is:  tensor(0.0359, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  184000
# alpha: (goal 0.191  tensor([0.3708], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2192], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0474], grad_fn=<MulBackward0>)
#
# Epoch  185000
#
# Epoch  186000
#
# Epoch  187000
#
# Epoch  188000
#
# Saving model... Loss is:  tensor(0.0334, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  188000
# alpha: (goal 0.191  tensor([0.3653], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2154], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0451], grad_fn=<MulBackward0>)
#
# Epoch  189000
#
# Epoch  190000
#
# Epoch  191000
#
# Epoch  192000
#
# Saving model... Loss is:  tensor(0.0310, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  192000
# alpha: (goal 0.191  tensor([0.3609], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2116], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0428], grad_fn=<MulBackward0>)
#
# Epoch  193000
#
# Epoch  194000
#
# Epoch  195000
#
# Epoch  196000
#
# Saving model... Loss is:  tensor(0.0288, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  196000
# alpha: (goal 0.191  tensor([0.3556], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2078], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0405], grad_fn=<MulBackward0>)
#
# Epoch  197000
#
# Epoch  198000
#
# Epoch  199000
#
# Epoch  200000
#
# Saving model... Loss is:  tensor(0.0266, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  200000
# alpha: (goal 0.191  tensor([0.3510], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2040], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0382], grad_fn=<MulBackward0>)
#
# Epoch  201000
#
# Epoch  202000
#
# Epoch  203000
#
# Epoch  204000
#
# Saving model... Loss is:  tensor(0.0247, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  204000
# alpha: (goal 0.191  tensor([0.3439], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.2001], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0358], grad_fn=<MulBackward0>)
#
# Epoch  205000
#
# Epoch  206000
#
# Epoch  207000
#
# Epoch  208000
#
# Saving model... Loss is:  tensor(0.0227, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  208000
# alpha: (goal 0.191  tensor([0.3409], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1963], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0335], grad_fn=<MulBackward0>)
#
# Epoch  209000
#
# Epoch  210000
#
# Epoch  211000
#
# Epoch  212000
#
# Saving model... Loss is:  tensor(0.0208, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  212000
# alpha: (goal 0.191  tensor([0.3374], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1924], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0312], grad_fn=<MulBackward0>)
#
# Epoch  213000
#
# Epoch  214000
#
# Epoch  215000
#
# Epoch  216000
#
# Saving model... Loss is:  tensor(0.0192, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  216000
# alpha: (goal 0.191  tensor([0.3331], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1886], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0289], grad_fn=<MulBackward0>)
#
# Epoch  217000
#
# Epoch  218000
#
# Epoch  219000
#
# Epoch  220000
#
# Saving model... Loss is:  tensor(0.0177, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  220000
# alpha: (goal 0.191  tensor([0.3293], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1848], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0266], grad_fn=<MulBackward0>)
#
# Epoch  221000
#
# Epoch  222000
#
# Epoch  223000
#
# Epoch  224000
#
# Saving model... Loss is:  tensor(0.0163, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  224000
# alpha: (goal 0.191  tensor([0.3258], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1809], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0243], grad_fn=<MulBackward0>)
#
# Epoch  225000
#
# Epoch  226000
#
# Epoch  227000
#
# Epoch  228000
#
# Saving model... Loss is:  tensor(0.0150, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  228000
# alpha: (goal 0.191  tensor([0.3224], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1771], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0220], grad_fn=<MulBackward0>)
#
# Epoch  229000
#
# Epoch  230000
#
# Epoch  231000
#
# Epoch  232000
#
# Saving model... Loss is:  tensor(0.0137, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  232000
# alpha: (goal 0.191  tensor([0.3180], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1732], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0197], grad_fn=<MulBackward0>)
#
# Epoch  233000
#
# Epoch  234000
#
# Epoch  235000
#
# Epoch  236000
#
# Saving model... Loss is:  tensor(0.0124, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  236000
# alpha: (goal 0.191  tensor([0.3132], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1693], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0174], grad_fn=<MulBackward0>)
#
# Epoch  237000
#
# Epoch  238000
#
# Epoch  239000
#
# Epoch  240000
#
# Saving model... Loss is:  tensor(0.0113, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  240000
# alpha: (goal 0.191  tensor([0.3083], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1655], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0152], grad_fn=<MulBackward0>)
#
# Epoch  241000
#
# Epoch  242000
#
# Epoch  243000
#
# Epoch  244000
#
# Saving model... Loss is:  tensor(0.0102, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  244000
# alpha: (goal 0.191  tensor([0.3029], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1616], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0129], grad_fn=<MulBackward0>)
#
# Epoch  245000
#
# Epoch  246000
#
# Epoch  247000
#
# Epoch  248000
#
# Saving model... Loss is:  tensor(0.0092, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  248000
# alpha: (goal 0.191  tensor([0.2965], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1577], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0106], grad_fn=<MulBackward0>)
#
# Epoch  249000
#
# Epoch  250000
#
# Epoch  251000
#
# Epoch  252000
#
# Saving model... Loss is:  tensor(0.0083, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  252000
# alpha: (goal 0.191  tensor([0.2895], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1538], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0083], grad_fn=<MulBackward0>)
#
# Epoch  253000
#
# Epoch  254000
#
# Epoch  255000
#
# Epoch  256000
#
# Saving model... Loss is:  tensor(0.0074, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  256000
# alpha: (goal 0.191  tensor([0.2825], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1499], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0061], grad_fn=<MulBackward0>)
#
# Epoch  257000
#
# Epoch  258000
#
# Epoch  259000
#
# Epoch  260000
#
# Saving model... Loss is:  tensor(0.0066, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  260000
# alpha: (goal 0.191  tensor([0.2754], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1460], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0039], grad_fn=<MulBackward0>)
#
# Epoch  261000
#
# Epoch  262000
#
# Epoch  263000
#
# Epoch  264000
#
# Saving model... Loss is:  tensor(0.0058, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  264000
# alpha: (goal 0.191  tensor([0.2682], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1421], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0018], grad_fn=<MulBackward0>)
#
# Epoch  265000
#
# Epoch  266000
#
# Epoch  267000
#
# Epoch  268000
#
# Saving model... Loss is:  tensor(0.0051, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  268000
# alpha: (goal 0.191  tensor([0.2614], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1382], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([-0.0001], grad_fn=<MulBackward0>)
#
# Epoch  269000
#
# Epoch  270000
#
# Epoch  271000
#
# Epoch  272000
#
# Saving model... Loss is:  tensor(0.0044, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  272000
# alpha: (goal 0.191  tensor([0.2557], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1344], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([-0.0014], grad_fn=<MulBackward0>)
#
# Epoch  273000
#
# Epoch  274000
#
# Epoch  275000
#
# Epoch  276000
#
# Saving model... Loss is:  tensor(0.0038, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  276000
# alpha: (goal 0.191  tensor([0.2528], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1304], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([-0.0007], grad_fn=<MulBackward0>)
#
# Epoch  277000
#
# Epoch  278000
#
# Epoch  279000
#
# Epoch  280000
#
# Saving model... Loss is:  tensor(0.0032, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  280000
# alpha: (goal 0.191  tensor([0.2510], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1265], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0004], grad_fn=<MulBackward0>)
#
# Epoch  281000
#
# Epoch  282000
#
# Epoch  283000
#
# Epoch  284000
#
# Saving model... Loss is:  tensor(0.0027, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  284000
# alpha: (goal 0.191  tensor([0.2476], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1226], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0009], grad_fn=<MulBackward0>)
#
# Epoch  285000
#
# Epoch  286000
#
# Epoch  287000
#
# Epoch  288000
#
# Saving model... Loss is:  tensor(0.0023, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  288000
# alpha: (goal 0.191  tensor([0.2461], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1187], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0023], grad_fn=<MulBackward0>)
#
# Epoch  289000
#
# Epoch  290000
#
# Epoch  291000
#
# Epoch  292000
#
# Saving model... Loss is:  tensor(0.0019, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  292000
# alpha: (goal 0.191  tensor([0.2451], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1148], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0040], grad_fn=<MulBackward0>)
#
# Epoch  293000
#
# Epoch  294000
#
# Epoch  295000
#
# Epoch  296000
#
# Saving model... Loss is:  tensor(0.0015, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  296000
# alpha: (goal 0.191  tensor([0.2435], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1109], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0053], grad_fn=<MulBackward0>)
#
# Epoch  297000
#
# Epoch  298000
#
# Epoch  299000
#
# Epoch  300000
#
# Saving model... Loss is:  tensor(0.0013, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  300000
# alpha: (goal 0.191  tensor([0.2420], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1070], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0068], grad_fn=<MulBackward0>)
#
# Epoch  301000
#
# Epoch  302000
#
# Epoch  303000
#
# Epoch  304000
#
# Saving model... Loss is:  tensor(0.0010, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  304000
# alpha: (goal 0.191  tensor([0.2394], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.1031], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0080], grad_fn=<MulBackward0>)
#
# Epoch  305000
#
# Epoch  306000
#
# Epoch  307000
#
# Epoch  308000
#
# Saving model... Loss is:  tensor(0.0009, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  308000
# alpha: (goal 0.191  tensor([0.2362], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0992], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0085], grad_fn=<MulBackward0>)
#
# Epoch  309000
#
# Epoch  310000
#
# Epoch  311000
#
# Epoch  312000
#
# Saving model... Loss is:  tensor(0.0007, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  312000
# alpha: (goal 0.191  tensor([0.2347], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0953], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0102], grad_fn=<MulBackward0>)
#
# Epoch  313000
#
# Epoch  314000
#
# Epoch  315000
#
# Epoch  316000
#
# Saving model... Loss is:  tensor(0.0006, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  316000
# alpha: (goal 0.191  tensor([0.2331], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0914], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0123], grad_fn=<MulBackward0>)
#
# Epoch  317000
#
# Epoch  318000
#
# Epoch  319000
#
# Epoch  320000
#
# Saving model... Loss is:  tensor(0.0005, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  320000
# alpha: (goal 0.191  tensor([0.2285], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0876], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0144], grad_fn=<MulBackward0>)
#
# Epoch  321000
#
# Epoch  322000
#
# Epoch  323000
#
# Epoch  324000
#
# Saving model... Loss is:  tensor(0.0005, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  324000
# alpha: (goal 0.191  tensor([0.2273], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0837], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0167], grad_fn=<MulBackward0>)
#
# Epoch  325000
#
# Epoch  326000
#
# Epoch  327000
#
# Epoch  328000
#
# Saving model... Loss is:  tensor(0.0004, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  328000
# alpha: (goal 0.191  tensor([0.2235], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0799], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0186], grad_fn=<MulBackward0>)
#
# Epoch  329000
#
# Epoch  330000
#
# Epoch  331000
#
# Epoch  332000
#
# Saving model... Loss is:  tensor(0.0004, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  332000
# alpha: (goal 0.191  tensor([0.2206], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0760], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0205], grad_fn=<MulBackward0>)
#
# Epoch  333000
#
# Epoch  334000
#
# Epoch  335000
#
# Epoch  336000
#
# Saving model... Loss is:  tensor(0.0004, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  336000
# alpha: (goal 0.191  tensor([0.2184], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0722], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0223], grad_fn=<MulBackward0>)
# CPU times: user 20min 54s, sys: 3.1 s, total: 20min 57s
# Wall time: 20min 59s

# %%
plt.plot(dinn.losses[300000:], color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss'),
# Out:
# (Text(0, 0.5, 'Loss'),)

# %%
fig = plt.figure(figsize=(12,12))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')


ax.plot(sidr_data[0], sidr_data[1], 'pink', alpha=0.5, lw=2, label='Susceptible')
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax.plot(sidr_data[0], sidr_data[2], 'violet', alpha=0.5, lw=2, label='Infected')
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax.plot(sidr_data[0], sidr_data[3], 'darkgreen', alpha=0.5, lw=2, label='Dead')
ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax.plot(sidr_data[0], sidr_data[4], 'blue', alpha=0.5, lw=2, label='Recovered')
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
#ax.set_ylim([-1,50])
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='black', lw=0.2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('itswhite.pdf')
plt.show()

# %%
#calculate relative MSE loss
import math
import numpy as np

S_total_loss = 0
S_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0
t = np.linspace(0, 500, 100) 

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S_pred_list[0].detach().numpy()[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2
  I_value = sidr_data[2][timestep] - I_pred_list[0].detach().numpy()[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[2][timestep])**2
  D_value = sidr_data[3][timestep] - D_pred_list[0].detach().numpy()[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[3][timestep])**2
  R_value = sidr_data[4][timestep] - R_pred_list[0].detach().numpy()[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[4][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S_total_loss: ', S_total_loss)
print('I_total_loss: ', I_total_loss)
print('D_total_loss: ', D_total_loss)
print('R_total_loss: ', R_total_loss)
# Out:
# S_total_loss:  0.008090153943225948
# I_total_loss:  0.015271797606912602
# D_total_loss:  0.0036822569986420775
# R_total_loss:  0.0033918703789738752

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial conditions
N = 59e6

S0 = N - 1
I0 = 1
D0 = 0
R0 = 0
# A grid of time points (in days)
t = np.linspace(0, 500, 100) 

#parameters
alpha = dinn.alpha
beta = dinn.beta
gamma = dinn.gamma

# The SIR model differential equations.
def deriv(y, t, alpha, betta, gamma):
    S, I, D, R = y
    dSdt = - (alpha / N) * S * I
    dIdt = (alpha / N) * S * I - beta * I - gamma * I 
    dDdt = gamma * I
    dRdt = beta * I

    return dSdt, dIdt, dDdt, dRdt


# Initial conditions vector
y0 = S0, I0, D0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(alpha, beta, gamma))
S, I, D, R = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(t, sidr_data[1], 'dodgerblue', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, I, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.plot(t, sidr_data[2], 'gold', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, D, 'red', alpha=0.5, lw=2, label='Learnable Param Dead', linestyle='dashed')
ax.plot(t, sidr_data[3], 'salmon', alpha=0.5, lw=2, label='Dead')

ax.plot(t, R, 'blue', alpha=0.5, lw=2, label='Learnable Param Recovered', linestyle='dashed')
ax.plot(t, sidr_data[4], 'wheat', alpha=0.5, lw=2, label='Recovered')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#calculate relative MSE loss
import math

S_total_loss = 0
S_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2
  I_value = sidr_data[2][timestep] - I[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[2][timestep])**2
  D_value = sidr_data[3][timestep] - D[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[3][timestep])**2
  R_value = sidr_data[4][timestep] - R[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[4][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S_total_loss: ', S_total_loss)
print('I_total_loss: ', I_total_loss)
print('D_total_loss: ', D_total_loss)
print('R_total_loss: ', R_total_loss)
# Out:
# S_total_loss:  0.13603453295058773
# I_total_loss:  0.590879873652992
# D_total_loss:  0.3659977756206916
# R_total_loss:  0.25914559751826366
