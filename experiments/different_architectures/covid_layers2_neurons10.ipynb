# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('covid_100_pts.csv', delimiter=',') #in the form of [t,S,I,D,R]

torch.manual_seed(1234)

# %%
# %%time

PATH = 'covid_layers2_neurons10_' 

class DINN(nn.Module):
    def __init__(self, t, S_data, I_data, D_data, R_data): #[t,S,I,D,R]
        super(DINN, self).__init__()
        self.N = 59e6 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.I = torch.tensor(I_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 3 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True)) #0.191
        self.beta_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True)) #0.05
        self.gamma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True)) #0.0294
        
        #find values for normalization
        self.S_max = max(self.S)
        self.I_max = max(self.I)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.I_min = min(self.I)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #unnormalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x4 for S,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 4)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 4)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 4)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 4)); self.m4[:, 3] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda, self.gamma_tilda]))

    #force parameters to be in a range
    @property
    def alpha(self):
        return torch.tanh(self.alpha_tilda)*0.191*20

    @property
    def beta(self):
        return torch.tanh(self.beta_tilda)*0.05*20
    
    @property
    def gamma(self):
        return torch.tanh(self.gamma_tilda)*0.0294*20


    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 10) #takes 100 t's
            self.fc2=nn.Linear(10, 10)
            self.out=nn.Linear(10, 4) #outputs S, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, I_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m2, retain_graph=True)
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m3, retain_graph=True)
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m4, retain_graph=True)
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-(self.alpha / self.N) * S * I)  / (self.S_max - self.S_min)
        f2_hat = I_hat_t - ((self.alpha / self.N) * S * I - self.beta * I - self.gamma * I ) / (self.I_max - self.I_min)
        f3_hat = D_hat_t - (self.gamma * I) / (self.D_max - self.D_min)
        f4_hat = R_hat_t - (self.beta * I ) / (self.R_max - self.R_min)


        return f1_hat, f2_hat, f3_hat, f4_hat, S_hat, I_hat, D_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        self.losses = checkpoint['losses']

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        I_pred_list = []
        D_pred_list = []
        R_pred_list = []

        f1, f2, f3, f4, S_pred, I_pred, D_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        loss = (torch.mean(torch.square(self.S_hat - S_pred))+ 
                torch.mean(torch.square(self.I_hat - I_pred))+
                torch.mean(torch.square(self.D_hat - D_pred))+
                torch.mean(torch.square(self.R_hat - R_pred))+
                torch.mean(torch.square(f1))+
                torch.mean(torch.square(f2))+
                torch.mean(torch.square(f3))+
                torch.mean(torch.square(f4))
                ) 

        loss.backward()
        self.optimizer.step()
        self.scheduler.step() 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)

        #loss + model parameters update
        if epoch % 4000 == 0:
          #checkpoint save every 100 epochs if the loss is lower
          print('\nSaving model... Loss is: ', loss)
          torch.save({
              'epoch': epoch,
              'model': self.state_dict(),
              'optimizer_state_dict': self.optimizer.state_dict(),
              'scheduler': self.scheduler.state_dict(),
              #'loss': loss,
              'losses': self.losses,
              }, PATH + str(self.save)+'.pt')
          if self.save % 2 > 0: #its on 3
            self.save = 2 #change to 2
          else: #its on 2
            self.save = 3 #change to 3

          print('epoch: ', epoch)
          print('alpha: (goal 0.191 ', self.alpha)
          print('beta: (goal 0.05 ', self.beta)
          print('gamma: (goal 0.0294 ', self.gamma)
        
      return S_pred_list, I_pred_list, D_pred_list, R_pred_list
# Out:
# CPU times: user 54 µs, sys: 0 ns, total: 54 µs
# Wall time: 58.4 µs

# %%
# %%time

dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[3], 
            sidr_data[4]) #in the form of [t,S,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)

dinn.scheduler = scheduler

try: 
  S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(700000) #train
except EOFError:
  if dinn.save == 2:
    dinn.save = 3
    S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(700000) #train
  elif dinn.save == 3:
    dinn.save = 2
    S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(700000) #train
# Out:
# loading pre-trained model...
#
# starting training...
#
#
# Epoch  0
#
# Saving model... Loss is:  tensor(0.0438, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  0
# alpha: (goal 0.191  tensor([0.0782], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0225], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0186], grad_fn=<MulBackward0>)
#
# Epoch  1000
#
# Epoch  2000
#
# Epoch  3000
#
# Epoch  4000
#
# Saving model... Loss is:  tensor(0.0431, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  4000
# alpha: (goal 0.191  tensor([0.0784], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0227], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0187], grad_fn=<MulBackward0>)
#
# Epoch  5000
#
# Epoch  6000
#
# Epoch  7000
#
# Epoch  8000
#
# Saving model... Loss is:  tensor(0.0425, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  8000
# alpha: (goal 0.191  tensor([0.0789], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0230], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0189], grad_fn=<MulBackward0>)
#
# Epoch  9000
#
# Epoch  10000
#
# Epoch  11000
#
# Epoch  12000
#
# Saving model... Loss is:  tensor(0.0419, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  12000
# alpha: (goal 0.191  tensor([0.0796], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0233], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0191], grad_fn=<MulBackward0>)
#
# Epoch  13000
#
# Epoch  14000
#
# Epoch  15000
#
# Epoch  16000
#
# Saving model... Loss is:  tensor(0.0413, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  16000
# alpha: (goal 0.191  tensor([0.0801], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0236], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0193], grad_fn=<MulBackward0>)
#
# Epoch  17000
#
# Epoch  18000
#
# Epoch  19000
#
# Epoch  20000
#
# Saving model... Loss is:  tensor(0.0407, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  20000
# alpha: (goal 0.191  tensor([0.0807], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0239], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0195], grad_fn=<MulBackward0>)
#
# Epoch  21000
#
# Epoch  22000
#
# Epoch  23000
#
# Epoch  24000
#
# Saving model... Loss is:  tensor(0.0401, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  24000
# alpha: (goal 0.191  tensor([0.0802], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0237], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0194], grad_fn=<MulBackward0>)
#
# Epoch  25000
#
# Epoch  26000
#
# Epoch  27000
#
# Epoch  28000
#
# Saving model... Loss is:  tensor(0.0395, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  28000
# alpha: (goal 0.191  tensor([0.0805], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0239], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0195], grad_fn=<MulBackward0>)
#
# Epoch  29000
#
# Epoch  30000
#
# Epoch  31000
#
# Epoch  32000
#
# Saving model... Loss is:  tensor(0.0389, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  32000
# alpha: (goal 0.191  tensor([0.0810], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0241], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0196], grad_fn=<MulBackward0>)
#
# Epoch  33000
#
# Epoch  34000
#
# Epoch  35000
#
# Epoch  36000
#
# Saving model... Loss is:  tensor(0.0383, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  36000
# alpha: (goal 0.191  tensor([0.0813], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0243], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0197], grad_fn=<MulBackward0>)
#
# Epoch  37000
#
# Epoch  38000
#
# Epoch  39000
#
# Epoch  40000
#
# Saving model... Loss is:  tensor(0.0377, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  40000
# alpha: (goal 0.191  tensor([0.0817], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0244], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0198], grad_fn=<MulBackward0>)
#
# Epoch  41000
#
# Epoch  42000
#
# Epoch  43000
#
# Epoch  44000
#
# Saving model... Loss is:  tensor(0.0372, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  44000
# alpha: (goal 0.191  tensor([0.0818], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0245], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0199], grad_fn=<MulBackward0>)
#
# Epoch  45000
#
# Epoch  46000
#
# Epoch  47000
#
# Epoch  48000
#
# Saving model... Loss is:  tensor(0.0366, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  48000
# alpha: (goal 0.191  tensor([0.0816], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0245], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0199], grad_fn=<MulBackward0>)
#
# Epoch  49000
#
# Epoch  50000
#
# Epoch  51000
#
# Epoch  52000
#
# Saving model... Loss is:  tensor(0.0360, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  52000
# alpha: (goal 0.191  tensor([0.0812], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0244], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0199], grad_fn=<MulBackward0>)
#
# Epoch  53000
#
# Epoch  54000
#
# Epoch  55000
#
# Epoch  56000
#
# Saving model... Loss is:  tensor(0.0354, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  56000
# alpha: (goal 0.191  tensor([0.0796], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0240], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0196], grad_fn=<MulBackward0>)
#
# Epoch  57000
#
# Epoch  58000
#
# Epoch  59000
#
# Epoch  60000
#
# Saving model... Loss is:  tensor(0.0349, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  60000
# alpha: (goal 0.191  tensor([0.0778], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0234], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0193], grad_fn=<MulBackward0>)
#
# Epoch  61000
#
# Epoch  62000
#
# Epoch  63000
#
# Epoch  64000
#
# Saving model... Loss is:  tensor(0.0344, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  64000
# alpha: (goal 0.191  tensor([0.0761], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0228], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0189], grad_fn=<MulBackward0>)
#
# Epoch  65000
#
# Epoch  66000
#
# Epoch  67000
#
# Epoch  68000
#
# Saving model... Loss is:  tensor(0.0338, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  68000
# alpha: (goal 0.191  tensor([0.0752], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0226], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0187], grad_fn=<MulBackward0>)
#
# Epoch  69000
#
# Epoch  70000
#
# Epoch  71000
#
# Epoch  72000
#
# Saving model... Loss is:  tensor(0.0333, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  72000
# alpha: (goal 0.191  tensor([0.0747], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0226], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0186], grad_fn=<MulBackward0>)
#
# Epoch  73000
#
# Epoch  74000
#
# Epoch  75000
#
# Epoch  76000
#
# Saving model... Loss is:  tensor(0.0331, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  76000
# alpha: (goal 0.191  tensor([0.0743], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0225], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0185], grad_fn=<MulBackward0>)
#
# Epoch  77000
#
# Epoch  78000
#
# Epoch  79000
#
# Epoch  80000
#
# Saving model... Loss is:  tensor(0.0323, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  80000
# alpha: (goal 0.191  tensor([0.0739], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0224], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0184], grad_fn=<MulBackward0>)
#
# Epoch  81000
#
# Epoch  82000
#
# Epoch  83000
#
# Epoch  84000
#
# Saving model... Loss is:  tensor(0.0322, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  84000
# alpha: (goal 0.191  tensor([0.0736], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0224], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0184], grad_fn=<MulBackward0>)
#
# Epoch  85000
#
# Epoch  86000
#
# Epoch  87000
#
# Epoch  88000
#
# Saving model... Loss is:  tensor(0.0317, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  88000
# alpha: (goal 0.191  tensor([0.0735], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0224], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0184], grad_fn=<MulBackward0>)
#
# Epoch  89000
#
# Epoch  90000
#
# Epoch  91000
#
# Epoch  92000
#
# Saving model... Loss is:  tensor(0.0309, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  92000
# alpha: (goal 0.191  tensor([0.0736], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0225], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0184], grad_fn=<MulBackward0>)
#
# Epoch  93000
#
# Epoch  94000
#
# Epoch  95000
#
# Epoch  96000
#
# Saving model... Loss is:  tensor(0.0308, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  96000
# alpha: (goal 0.191  tensor([0.0738], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0226], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0185], grad_fn=<MulBackward0>)
#
# Epoch  97000
#
# Epoch  98000
#
# Epoch  99000
#
# Epoch  100000
#
# Saving model... Loss is:  tensor(0.0304, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  100000
# alpha: (goal 0.191  tensor([0.0740], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0227], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0185], grad_fn=<MulBackward0>)
#
# Epoch  101000
#
# Epoch  102000
#
# Epoch  103000
#
# Epoch  104000
#
# Saving model... Loss is:  tensor(0.0296, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  104000
# alpha: (goal 0.191  tensor([0.0747], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0228], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0187], grad_fn=<MulBackward0>)
#
# Epoch  105000
#
# Epoch  106000
#
# Epoch  107000
#
# Epoch  108000
#
# Saving model... Loss is:  tensor(0.0292, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  108000
# alpha: (goal 0.191  tensor([0.0748], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0228], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0188], grad_fn=<MulBackward0>)
#
# Epoch  109000
#
# Epoch  110000
#
# Epoch  111000
#
# Epoch  112000
#
# Saving model... Loss is:  tensor(0.0291, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  112000
# alpha: (goal 0.191  tensor([0.0751], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0229], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0189], grad_fn=<MulBackward0>)
#
# Epoch  113000
#
# Epoch  114000
#
# Epoch  115000
#
# Epoch  116000
#
# Saving model... Loss is:  tensor(0.0283, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  116000
# alpha: (goal 0.191  tensor([0.0755], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0231], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0190], grad_fn=<MulBackward0>)
#
# Epoch  117000
#
# Epoch  118000
#
# Epoch  119000
#
# Epoch  120000
#
# Saving model... Loss is:  tensor(0.0279, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  120000
# alpha: (goal 0.191  tensor([0.0756], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0232], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0191], grad_fn=<MulBackward0>)
#
# Epoch  121000
#
# Epoch  122000
#
# Epoch  123000
#
# Epoch  124000
#
# Saving model... Loss is:  tensor(0.0276, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  124000
# alpha: (goal 0.191  tensor([0.0743], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0228], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0188], grad_fn=<MulBackward0>)
#
# Epoch  125000
#
# Epoch  126000
#
# Epoch  127000
#
# Epoch  128000
#
# Saving model... Loss is:  tensor(0.0276, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  128000
# alpha: (goal 0.191  tensor([0.0733], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0226], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0186], grad_fn=<MulBackward0>)
#
# Epoch  129000
#
# Epoch  130000
#
# Epoch  131000
#
# Epoch  132000
#
# Saving model... Loss is:  tensor(0.0272, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  132000
# alpha: (goal 0.191  tensor([0.0730], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0227], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0185], grad_fn=<MulBackward0>)
#
# Epoch  133000
#
# Epoch  134000
#
# Epoch  135000
#
# Epoch  136000
#
# Saving model... Loss is:  tensor(0.0265, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  136000
# alpha: (goal 0.191  tensor([0.0729], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0227], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0184], grad_fn=<MulBackward0>)
#
# Epoch  137000
#
# Epoch  138000
#
# Epoch  139000
#
# Epoch  140000
#
# Saving model... Loss is:  tensor(0.0265, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  140000
# alpha: (goal 0.191  tensor([0.0726], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0228], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0183], grad_fn=<MulBackward0>)
#
# Epoch  141000
#
# Epoch  142000
#
# Epoch  143000
#
# Epoch  144000
#
# Saving model... Loss is:  tensor(0.0262, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  144000
# alpha: (goal 0.191  tensor([0.0723], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0228], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0182], grad_fn=<MulBackward0>)
#
# Epoch  145000
#
# Epoch  146000
#
# Epoch  147000
#
# Epoch  148000
#
# Saving model... Loss is:  tensor(0.0258, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  148000
# alpha: (goal 0.191  tensor([0.0716], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0227], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0180], grad_fn=<MulBackward0>)
#
# Epoch  149000
#
# Epoch  150000
#
# Epoch  151000
#
# Epoch  152000
#
# Saving model... Loss is:  tensor(0.0255, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  152000
# alpha: (goal 0.191  tensor([0.0703], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0224], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0177], grad_fn=<MulBackward0>)
#
# Epoch  153000
#
# Epoch  154000
#
# Epoch  155000
#
# Epoch  156000
#
# Saving model... Loss is:  tensor(0.0252, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  156000
# alpha: (goal 0.191  tensor([0.0728], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0230], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0181], grad_fn=<MulBackward0>)
#
# Epoch  157000
#
# Epoch  158000
#
# Epoch  159000
#
# Epoch  160000
#
# Saving model... Loss is:  tensor(0.0249, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  160000
# alpha: (goal 0.191  tensor([0.0707], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0223], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0177], grad_fn=<MulBackward0>)
#
# Epoch  161000
#
# Epoch  162000
#
# Epoch  163000
#
# Epoch  164000
#
# Saving model... Loss is:  tensor(0.0245, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  164000
# alpha: (goal 0.191  tensor([0.0678], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0216], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0170], grad_fn=<MulBackward0>)
#
# Epoch  165000
#
# Epoch  166000
#
# Epoch  167000
#
# Epoch  168000
#
# Saving model... Loss is:  tensor(0.0242, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  168000
# alpha: (goal 0.191  tensor([0.0654], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0213], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0162], grad_fn=<MulBackward0>)
#
# Epoch  169000
#
# Epoch  170000
#
# Epoch  171000
#
# Epoch  172000
#
# Saving model... Loss is:  tensor(0.0239, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  172000
# alpha: (goal 0.191  tensor([0.0660], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0216], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0163], grad_fn=<MulBackward0>)
#
# Epoch  173000
#
# Epoch  174000
#
# Epoch  175000
#
# Epoch  176000
#
# Saving model... Loss is:  tensor(0.0236, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  176000
# alpha: (goal 0.191  tensor([0.0666], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0218], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0165], grad_fn=<MulBackward0>)
#
# Epoch  177000
#
# Epoch  178000
#
# Epoch  179000
#
# Epoch  180000
#
# Saving model... Loss is:  tensor(0.0233, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  180000
# alpha: (goal 0.191  tensor([0.0672], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0220], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0166], grad_fn=<MulBackward0>)
#
# Epoch  181000
#
# Epoch  182000
#
# Epoch  183000
#
# Epoch  184000
#
# Saving model... Loss is:  tensor(0.0230, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  184000
# alpha: (goal 0.191  tensor([0.0678], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0223], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0168], grad_fn=<MulBackward0>)
#
# Epoch  185000
#
# Epoch  186000
#
# Epoch  187000
#
# Epoch  188000
#
# Saving model... Loss is:  tensor(0.0227, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  188000
# alpha: (goal 0.191  tensor([0.0684], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0226], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0169], grad_fn=<MulBackward0>)
#
# Epoch  189000
#
# Epoch  190000
#
# Epoch  191000
#
# Epoch  192000
#
# Saving model... Loss is:  tensor(0.0224, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  192000
# alpha: (goal 0.191  tensor([0.0690], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0228], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0171], grad_fn=<MulBackward0>)
#
# Epoch  193000
#
# Epoch  194000
#
# Epoch  195000
#
# Epoch  196000
#
# Saving model... Loss is:  tensor(0.0221, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  196000
# alpha: (goal 0.191  tensor([0.0697], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0231], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0172], grad_fn=<MulBackward0>)
#
# Epoch  197000
#
# Epoch  198000
#
# Epoch  199000
#
# Epoch  200000
#
# Saving model... Loss is:  tensor(0.0218, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  200000
# alpha: (goal 0.191  tensor([0.0703], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0233], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0174], grad_fn=<MulBackward0>)
#
# Epoch  201000
#
# Epoch  202000
#
# Epoch  203000
#
# Epoch  204000
#
# Saving model... Loss is:  tensor(0.0215, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  204000
# alpha: (goal 0.191  tensor([0.0710], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0236], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0175], grad_fn=<MulBackward0>)
#
# Epoch  205000
#
# Epoch  206000
#
# Epoch  207000
#
# Epoch  208000
#
# Saving model... Loss is:  tensor(0.0212, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  208000
# alpha: (goal 0.191  tensor([0.0718], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0238], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0176], grad_fn=<MulBackward0>)
#
# Epoch  209000
#
# Epoch  210000
#
# Epoch  211000
#
# Epoch  212000
#
# Saving model... Loss is:  tensor(0.0209, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  212000
# alpha: (goal 0.191  tensor([0.0726], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0241], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0177], grad_fn=<MulBackward0>)
#
# Epoch  213000
#
# Epoch  214000
#
# Epoch  215000
#
# Epoch  216000
#
# Saving model... Loss is:  tensor(0.0206, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  216000
# alpha: (goal 0.191  tensor([0.0734], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0243], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0179], grad_fn=<MulBackward0>)
#
# Epoch  217000
#
# Epoch  218000
#
# Epoch  219000
#
# Epoch  220000
#
# Saving model... Loss is:  tensor(0.0203, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  220000
# alpha: (goal 0.191  tensor([0.0742], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0180], grad_fn=<MulBackward0>)
#
# Epoch  221000
#
# Epoch  222000
#
# Epoch  223000
#
# Epoch  224000
#
# Saving model... Loss is:  tensor(0.0200, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  224000
# alpha: (goal 0.191  tensor([0.0750], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0248], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0181], grad_fn=<MulBackward0>)
#
# Epoch  225000
#
# Epoch  226000
#
# Epoch  227000
#
# Epoch  228000
#
# Saving model... Loss is:  tensor(0.0197, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  228000
# alpha: (goal 0.191  tensor([0.0758], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0183], grad_fn=<MulBackward0>)
#
# Epoch  229000
#
# Epoch  230000
#
# Epoch  231000
#
# Epoch  232000
#
# Saving model... Loss is:  tensor(0.0194, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  232000
# alpha: (goal 0.191  tensor([0.0767], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0254], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0184], grad_fn=<MulBackward0>)
#
# Epoch  233000
#
# Epoch  234000
#
# Epoch  235000
#
# Epoch  236000
#
# Saving model... Loss is:  tensor(0.0191, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  236000
# alpha: (goal 0.191  tensor([0.0775], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0256], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0185], grad_fn=<MulBackward0>)
#
# Epoch  237000
#
# Epoch  238000
#
# Epoch  239000
#
# Epoch  240000
#
# Saving model... Loss is:  tensor(0.0188, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  240000
# alpha: (goal 0.191  tensor([0.0784], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0259], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0187], grad_fn=<MulBackward0>)
#
# Epoch  241000
#
# Epoch  242000
#
# Epoch  243000
#
# Epoch  244000
#
# Saving model... Loss is:  tensor(0.0186, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  244000
# alpha: (goal 0.191  tensor([0.0793], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0262], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0188], grad_fn=<MulBackward0>)
#
# Epoch  245000
#
# Epoch  246000
#
# Epoch  247000
#
# Epoch  248000
#
# Saving model... Loss is:  tensor(0.0183, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  248000
# alpha: (goal 0.191  tensor([0.0802], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0265], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0189], grad_fn=<MulBackward0>)
#
# Epoch  249000
#
# Epoch  250000
#
# Epoch  251000
#
# Epoch  252000
#
# Saving model... Loss is:  tensor(0.0180, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  252000
# alpha: (goal 0.191  tensor([0.0812], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0267], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0191], grad_fn=<MulBackward0>)
#
# Epoch  253000
#
# Epoch  254000
#
# Epoch  255000
#
# Epoch  256000
#
# Saving model... Loss is:  tensor(0.0177, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  256000
# alpha: (goal 0.191  tensor([0.0821], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0270], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0192], grad_fn=<MulBackward0>)
#
# Epoch  257000
#
# Epoch  258000
#
# Epoch  259000
#
# Epoch  260000
#
# Saving model... Loss is:  tensor(0.0174, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  260000
# alpha: (goal 0.191  tensor([0.0830], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0273], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0193], grad_fn=<MulBackward0>)
#
# Epoch  261000
#
# Epoch  262000
#
# Epoch  263000
#
# Epoch  264000
#
# Saving model... Loss is:  tensor(0.0171, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  264000
# alpha: (goal 0.191  tensor([0.0840], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0276], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0195], grad_fn=<MulBackward0>)
#
# Epoch  265000
#
# Epoch  266000
#
# Epoch  267000
#
# Epoch  268000
#
# Saving model... Loss is:  tensor(0.0168, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  268000
# alpha: (goal 0.191  tensor([0.0850], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0279], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0196], grad_fn=<MulBackward0>)
#
# Epoch  269000
#
# Epoch  270000
#
# Epoch  271000
#
# Epoch  272000
#
# Saving model... Loss is:  tensor(0.0165, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  272000
# alpha: (goal 0.191  tensor([0.0860], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0282], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0197], grad_fn=<MulBackward0>)
#
# Epoch  273000
#
# Epoch  274000
#
# Epoch  275000
#
# Epoch  276000
#
# Saving model... Loss is:  tensor(0.0162, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  276000
# alpha: (goal 0.191  tensor([0.0870], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0285], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0199], grad_fn=<MulBackward0>)
#
# Epoch  277000
#
# Epoch  278000
#
# Epoch  279000
#
# Epoch  280000
#
# Saving model... Loss is:  tensor(0.0159, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  280000
# alpha: (goal 0.191  tensor([0.0881], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0288], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0200], grad_fn=<MulBackward0>)
#
# Epoch  281000
#
# Epoch  282000
#
# Epoch  283000
#
# Epoch  284000
#
# Saving model... Loss is:  tensor(0.0157, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  284000
# alpha: (goal 0.191  tensor([0.0892], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0291], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0201], grad_fn=<MulBackward0>)
#
# Epoch  285000
#
# Epoch  286000
#
# Epoch  287000
#
# Epoch  288000
#
# Saving model... Loss is:  tensor(0.0154, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  288000
# alpha: (goal 0.191  tensor([0.0903], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0294], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0203], grad_fn=<MulBackward0>)
#
# Epoch  289000
#
# Epoch  290000
#
# Epoch  291000
#
# Epoch  292000
#
# Saving model... Loss is:  tensor(0.0151, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  292000
# alpha: (goal 0.191  tensor([0.0863], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0285], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0196], grad_fn=<MulBackward0>)
#
# Epoch  293000
#
# Epoch  294000
#
# Epoch  295000
#
# Epoch  296000
#
# Saving model... Loss is:  tensor(0.0148, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  296000
# alpha: (goal 0.191  tensor([0.0871], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0288], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0197], grad_fn=<MulBackward0>)
#
# Epoch  297000
#
# Epoch  298000
#
# Epoch  299000
#
# Epoch  300000
#
# Saving model... Loss is:  tensor(0.0145, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  300000
# alpha: (goal 0.191  tensor([0.0882], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0291], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0198], grad_fn=<MulBackward0>)
#
# Epoch  301000
#
# Epoch  302000
#
# Epoch  303000
#
# Epoch  304000
#
# Saving model... Loss is:  tensor(0.0143, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  304000
# alpha: (goal 0.191  tensor([0.0895], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0293], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0200], grad_fn=<MulBackward0>)
#
# Epoch  305000
#
# Epoch  306000
#
# Epoch  307000
#
# Epoch  308000
#
# Saving model... Loss is:  tensor(0.0140, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  308000
# alpha: (goal 0.191  tensor([0.0919], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0300], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0204], grad_fn=<MulBackward0>)
#
# Epoch  309000
#
# Epoch  310000
#
# Epoch  311000
#
# Epoch  312000
#
# Saving model... Loss is:  tensor(0.0138, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  312000
# alpha: (goal 0.191  tensor([0.0942], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0307], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0207], grad_fn=<MulBackward0>)
#
# Epoch  313000
#
# Epoch  314000
#
# Epoch  315000
#
# Epoch  316000
#
# Saving model... Loss is:  tensor(0.0135, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  316000
# alpha: (goal 0.191  tensor([0.0948], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0309], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0207], grad_fn=<MulBackward0>)
#
# Epoch  317000
#
# Epoch  318000
#
# Epoch  319000
#
# Epoch  320000
#
# Saving model... Loss is:  tensor(0.0133, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  320000
# alpha: (goal 0.191  tensor([0.0956], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0310], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0208], grad_fn=<MulBackward0>)
#
# Epoch  321000
#
# Epoch  322000
#
# Epoch  323000
#
# Epoch  324000
#
# Saving model... Loss is:  tensor(0.0130, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  324000
# alpha: (goal 0.191  tensor([0.0974], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0314], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0210], grad_fn=<MulBackward0>)
#
# Epoch  325000
#
# Epoch  326000
#
# Epoch  327000
#
# Epoch  328000
#
# Saving model... Loss is:  tensor(0.0128, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  328000
# alpha: (goal 0.191  tensor([0.0992], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0319], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0213], grad_fn=<MulBackward0>)
#
# Epoch  329000
#
# Epoch  330000
#
# Epoch  331000
#
# Epoch  332000
#
# Saving model... Loss is:  tensor(0.0126, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  332000
# alpha: (goal 0.191  tensor([0.1009], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0323], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0215], grad_fn=<MulBackward0>)
#
# Epoch  333000
#
# Epoch  334000
#
# Epoch  335000
#
# Epoch  336000
#
# Saving model... Loss is:  tensor(0.0124, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  336000
# alpha: (goal 0.191  tensor([0.1025], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0327], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0217], grad_fn=<MulBackward0>)
#
# Epoch  337000
#
# Epoch  338000
#
# Epoch  339000
#
# Epoch  340000
#
# Saving model... Loss is:  tensor(0.0122, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  340000
# alpha: (goal 0.191  tensor([0.1041], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0331], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0219], grad_fn=<MulBackward0>)
#
# Epoch  341000
#
# Epoch  342000
#
# Epoch  343000
#
# Epoch  344000
#
# Saving model... Loss is:  tensor(0.0120, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  344000
# alpha: (goal 0.191  tensor([0.1056], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0334], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0220], grad_fn=<MulBackward0>)
#
# Epoch  345000
#
# Epoch  346000
#
# Epoch  347000
#
# Epoch  348000
#
# Saving model... Loss is:  tensor(0.0118, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  348000
# alpha: (goal 0.191  tensor([0.1070], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0337], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0221], grad_fn=<MulBackward0>)
#
# Epoch  349000
#
# Epoch  350000
#
# Epoch  351000
#
# Epoch  352000
#
# Saving model... Loss is:  tensor(0.0116, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  352000
# alpha: (goal 0.191  tensor([0.1083], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0340], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0223], grad_fn=<MulBackward0>)
#
# Epoch  353000
#
# Epoch  354000
#
# Epoch  355000
#
# Epoch  356000
#
# Saving model... Loss is:  tensor(0.0114, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  356000
# alpha: (goal 0.191  tensor([0.1095], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0343], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0224], grad_fn=<MulBackward0>)
#
# Epoch  357000
#
# Epoch  358000
#
# Epoch  359000
#
# Epoch  360000
#
# Saving model... Loss is:  tensor(0.0112, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  360000
# alpha: (goal 0.191  tensor([0.1108], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0345], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0225], grad_fn=<MulBackward0>)
#
# Epoch  361000
#
# Epoch  362000
#
# Epoch  363000
#
# Epoch  364000
#
# Saving model... Loss is:  tensor(0.0110, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  364000
# alpha: (goal 0.191  tensor([0.1122], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0347], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0226], grad_fn=<MulBackward0>)
#
# Epoch  365000
#
# Epoch  366000
#
# Epoch  367000
#
# Epoch  368000
#
# Saving model... Loss is:  tensor(0.0108, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  368000
# alpha: (goal 0.191  tensor([0.1135], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0350], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0227], grad_fn=<MulBackward0>)
#
# Epoch  369000
#
# Epoch  370000
#
# Epoch  371000
#
# Epoch  372000
#
# Saving model... Loss is:  tensor(0.0107, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  372000
# alpha: (goal 0.191  tensor([0.1147], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0351], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0228], grad_fn=<MulBackward0>)
#
# Epoch  373000
#
# Epoch  374000
#
# Epoch  375000
#
# Epoch  376000
#
# Saving model... Loss is:  tensor(0.0105, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  376000
# alpha: (goal 0.191  tensor([0.1159], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0353], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0228], grad_fn=<MulBackward0>)
#
# Epoch  377000
#
# Epoch  378000
#
# Epoch  379000
#
# Epoch  380000
#
# Saving model... Loss is:  tensor(0.0103, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  380000
# alpha: (goal 0.191  tensor([0.1171], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0354], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0229], grad_fn=<MulBackward0>)
#
# Epoch  381000
#
# Epoch  382000
#
# Epoch  383000
#
# Epoch  384000
#
# Saving model... Loss is:  tensor(0.0101, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  384000
# alpha: (goal 0.191  tensor([0.1182], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0356], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0230], grad_fn=<MulBackward0>)
#
# Epoch  385000
#
# Epoch  386000
#
# Epoch  387000
#
# Epoch  388000
#
# Saving model... Loss is:  tensor(0.0100, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  388000
# alpha: (goal 0.191  tensor([0.1194], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0357], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0231], grad_fn=<MulBackward0>)
#
# Epoch  389000
#
# Epoch  390000
#
# Epoch  391000
#
# Epoch  392000
#
# Saving model... Loss is:  tensor(0.0098, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  392000
# alpha: (goal 0.191  tensor([0.1205], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0358], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0231], grad_fn=<MulBackward0>)
#
# Epoch  393000
#
# Epoch  394000
#
# Epoch  395000
#
# Epoch  396000
#
# Saving model... Loss is:  tensor(0.0097, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  396000
# alpha: (goal 0.191  tensor([0.1217], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0360], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0232], grad_fn=<MulBackward0>)
#
# Epoch  397000
#
# Epoch  398000
#
# Epoch  399000
#
# Epoch  400000
#
# Saving model... Loss is:  tensor(0.0095, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  400000
# alpha: (goal 0.191  tensor([0.1228], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0361], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0233], grad_fn=<MulBackward0>)
#
# Epoch  401000
#
# Epoch  402000
#
# Epoch  403000
#
# Epoch  404000
#
# Saving model... Loss is:  tensor(0.0094, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  404000
# alpha: (goal 0.191  tensor([0.1239], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0363], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0234], grad_fn=<MulBackward0>)
#
# Epoch  405000
#
# Epoch  406000
#
# Epoch  407000
#
# Epoch  408000
#
# Saving model... Loss is:  tensor(0.0092, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  408000
# alpha: (goal 0.191  tensor([0.1250], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0364], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0234], grad_fn=<MulBackward0>)
#
# Epoch  409000
#
# Epoch  410000
#
# Epoch  411000
#
# Epoch  412000
#
# Saving model... Loss is:  tensor(0.0091, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  412000
# alpha: (goal 0.191  tensor([0.1262], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0366], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0235], grad_fn=<MulBackward0>)
#
# Epoch  413000
#
# Epoch  414000
#
# Epoch  415000
#
# Epoch  416000
#
# Saving model... Loss is:  tensor(0.0089, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  416000
# alpha: (goal 0.191  tensor([0.1274], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0368], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0236], grad_fn=<MulBackward0>)
#
# Epoch  417000
#
# Epoch  418000
#
# Epoch  419000
#
# Epoch  420000
#
# Saving model... Loss is:  tensor(0.0088, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  420000
# alpha: (goal 0.191  tensor([0.1286], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0370], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0237], grad_fn=<MulBackward0>)
#
# Epoch  421000
#
# Epoch  422000
#
# Epoch  423000
#
# Epoch  424000
#
# Saving model... Loss is:  tensor(0.0086, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  424000
# alpha: (goal 0.191  tensor([0.1298], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0372], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0237], grad_fn=<MulBackward0>)
#
# Epoch  425000
#
# Epoch  426000
#
# Epoch  427000
#
# Epoch  428000
#
# Saving model... Loss is:  tensor(0.0085, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  428000
# alpha: (goal 0.191  tensor([0.1309], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0374], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0238], grad_fn=<MulBackward0>)
#
# Epoch  429000
#
# Epoch  430000
#
# Epoch  431000
#
# Epoch  432000
#
# Saving model... Loss is:  tensor(0.0084, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  432000
# alpha: (goal 0.191  tensor([0.1321], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0376], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0238], grad_fn=<MulBackward0>)
#
# Epoch  433000
#
# Epoch  434000
#
# Epoch  435000
#
# Epoch  436000
#
# Saving model... Loss is:  tensor(0.0082, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  436000
# alpha: (goal 0.191  tensor([0.1332], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0377], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0239], grad_fn=<MulBackward0>)
#
# Epoch  437000
#
# Epoch  438000
#
# Epoch  439000
#
# Epoch  440000
#
# Saving model... Loss is:  tensor(0.0081, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  440000
# alpha: (goal 0.191  tensor([0.1343], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0379], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0240], grad_fn=<MulBackward0>)
#
# Epoch  441000
#
# Epoch  442000
#
# Epoch  443000
#
# Epoch  444000
#
# Saving model... Loss is:  tensor(0.0080, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  444000
# alpha: (goal 0.191  tensor([0.1355], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0381], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0240], grad_fn=<MulBackward0>)
#
# Epoch  445000
#
# Epoch  446000
#
# Epoch  447000
#
# Epoch  448000
#
# Saving model... Loss is:  tensor(0.0078, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  448000
# alpha: (goal 0.191  tensor([0.1366], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0383], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0241], grad_fn=<MulBackward0>)
#
# Epoch  449000
#
# Epoch  450000
#
# Epoch  451000
#
# Epoch  452000
#
# Saving model... Loss is:  tensor(0.0077, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  452000
# alpha: (goal 0.191  tensor([0.1377], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0385], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0241], grad_fn=<MulBackward0>)
#
# Epoch  453000
#
# Epoch  454000
#
# Epoch  455000
#
# Epoch  456000
#
# Saving model... Loss is:  tensor(0.0076, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  456000
# alpha: (goal 0.191  tensor([0.1389], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0387], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0242], grad_fn=<MulBackward0>)
#
# Epoch  457000
#
# Epoch  458000
#
# Epoch  459000
#
# Epoch  460000
#
# Saving model... Loss is:  tensor(0.0075, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  460000
# alpha: (goal 0.191  tensor([0.1399], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0389], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0243], grad_fn=<MulBackward0>)
#
# Epoch  461000
#
# Epoch  462000
#
# Epoch  463000
#
# Epoch  464000
#
# Saving model... Loss is:  tensor(0.0073, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  464000
# alpha: (goal 0.191  tensor([0.1410], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0391], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0243], grad_fn=<MulBackward0>)
#
# Epoch  465000
#
# Epoch  466000
#
# Epoch  467000
#
# Epoch  468000
#
# Saving model... Loss is:  tensor(0.0072, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  468000
# alpha: (goal 0.191  tensor([0.1421], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0393], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0243], grad_fn=<MulBackward0>)
#
# Epoch  469000
#
# Epoch  470000
#
# Epoch  471000
#
# Epoch  472000
#
# Saving model... Loss is:  tensor(0.0071, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  472000
# alpha: (goal 0.191  tensor([0.1434], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0397], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0244], grad_fn=<MulBackward0>)
#
# Epoch  473000
#
# Epoch  474000
#
# Epoch  475000
#
# Epoch  476000
#
# Saving model... Loss is:  tensor(0.0070, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  476000
# alpha: (goal 0.191  tensor([0.1445], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0399], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0244], grad_fn=<MulBackward0>)
#
# Epoch  477000
#
# Epoch  478000
#
# Epoch  479000
#
# Epoch  480000
#
# Saving model... Loss is:  tensor(0.0068, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  480000
# alpha: (goal 0.191  tensor([0.1452], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0399], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0244], grad_fn=<MulBackward0>)
#
# Epoch  481000
#
# Epoch  482000
#
# Epoch  483000
#
# Epoch  484000
#
# Saving model... Loss is:  tensor(0.0067, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  484000
# alpha: (goal 0.191  tensor([0.1460], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0401], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0245], grad_fn=<MulBackward0>)
#
# Epoch  485000
#
# Epoch  486000
#
# Epoch  487000
#
# Epoch  488000
#
# Saving model... Loss is:  tensor(0.0066, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  488000
# alpha: (goal 0.191  tensor([0.1461], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0401], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0244], grad_fn=<MulBackward0>)
#
# Epoch  489000
#
# Epoch  490000
#
# Epoch  491000
#
# Epoch  492000
#
# Saving model... Loss is:  tensor(0.0064, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  492000
# alpha: (goal 0.191  tensor([0.1463], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0401], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0244], grad_fn=<MulBackward0>)
#
# Epoch  493000
#
# Epoch  494000
#
# Epoch  495000
#
# Epoch  496000
#
# Saving model... Loss is:  tensor(0.0063, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  496000
# alpha: (goal 0.191  tensor([0.1468], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0402], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0244], grad_fn=<MulBackward0>)
#
# Epoch  497000
#
# Epoch  498000
#
# Epoch  499000
#
# Epoch  500000
#
# Saving model... Loss is:  tensor(0.0061, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  500000
# alpha: (goal 0.191  tensor([0.1476], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0403], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0243], grad_fn=<MulBackward0>)
#
# Epoch  501000
#
# Epoch  502000
#
# Epoch  503000
#
# Epoch  504000
#
# Saving model... Loss is:  tensor(0.0060, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  504000
# alpha: (goal 0.191  tensor([0.1492], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0407], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0246], grad_fn=<MulBackward0>)
#
# Epoch  505000
#
# Epoch  506000
#
# Epoch  507000
#
# Epoch  508000
#
# Saving model... Loss is:  tensor(0.0059, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  508000
# alpha: (goal 0.191  tensor([0.1500], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0409], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0246], grad_fn=<MulBackward0>)
#
# Epoch  509000
#
# Epoch  510000
#
# Epoch  511000
#
# Epoch  512000
#
# Saving model... Loss is:  tensor(0.0058, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  512000
# alpha: (goal 0.191  tensor([0.1505], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0410], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0246], grad_fn=<MulBackward0>)
#
# Epoch  513000
#
# Epoch  514000
#
# Epoch  515000
#
# Epoch  516000
#
# Saving model... Loss is:  tensor(0.0056, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  516000
# alpha: (goal 0.191  tensor([0.1517], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0411], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0246], grad_fn=<MulBackward0>)
#
# Epoch  517000
#
# Epoch  518000
#
# Epoch  519000
#
# Epoch  520000
#
# Saving model... Loss is:  tensor(0.0055, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  520000
# alpha: (goal 0.191  tensor([0.1519], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0413], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0247], grad_fn=<MulBackward0>)
#
# Epoch  521000
#
# Epoch  522000
#
# Epoch  523000
#
# Epoch  524000
#
# Saving model... Loss is:  tensor(0.0053, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  524000
# alpha: (goal 0.191  tensor([0.1529], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0416], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0248], grad_fn=<MulBackward0>)
#
# Epoch  525000
#
# Epoch  526000
#
# Epoch  527000
#
# Epoch  528000
#
# Saving model... Loss is:  tensor(0.0052, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  528000
# alpha: (goal 0.191  tensor([0.1540], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0419], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0249], grad_fn=<MulBackward0>)
#
# Epoch  529000
#
# Epoch  530000
#
# Epoch  531000
#
# Epoch  532000
#
# Saving model... Loss is:  tensor(0.0051, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  532000
# alpha: (goal 0.191  tensor([0.1551], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0422], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0250], grad_fn=<MulBackward0>)
#
# Epoch  533000
#
# Epoch  534000
#
# Epoch  535000
#
# Epoch  536000
#
# Saving model... Loss is:  tensor(0.0050, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  536000
# alpha: (goal 0.191  tensor([0.1562], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0424], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0251], grad_fn=<MulBackward0>)
#
# Epoch  537000
#
# Epoch  538000
#
# Epoch  539000
#
# Epoch  540000
#
# Saving model... Loss is:  tensor(0.0049, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  540000
# alpha: (goal 0.191  tensor([0.1573], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0427], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0252], grad_fn=<MulBackward0>)
#
# Epoch  541000
#
# Epoch  542000
#
# Epoch  543000
#
# Epoch  544000
#
# Saving model... Loss is:  tensor(0.0048, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  544000
# alpha: (goal 0.191  tensor([0.1608], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0435], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0255], grad_fn=<MulBackward0>)
#
# Epoch  545000
#
# Epoch  546000
#
# Epoch  547000
#
# Epoch  548000
#
# Saving model... Loss is:  tensor(0.0047, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  548000
# alpha: (goal 0.191  tensor([0.1639], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0442], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0258], grad_fn=<MulBackward0>)
#
# Epoch  549000
#
# Epoch  550000
#
# Epoch  551000
#
# Epoch  552000
#
# Saving model... Loss is:  tensor(0.0046, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  552000
# alpha: (goal 0.191  tensor([0.1670], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0449], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0262], grad_fn=<MulBackward0>)
#
# Epoch  553000
#
# Epoch  554000
#
# Epoch  555000
#
# Epoch  556000
#
# Saving model... Loss is:  tensor(0.0045, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  556000
# alpha: (goal 0.191  tensor([0.1703], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0456], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0266], grad_fn=<MulBackward0>)
#
# Epoch  557000
#
# Epoch  558000
#
# Epoch  559000
#
# Epoch  560000
#
# Saving model... Loss is:  tensor(0.0044, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  560000
# alpha: (goal 0.191  tensor([0.1736], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0464], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0270], grad_fn=<MulBackward0>)
#
# Epoch  561000
#
# Epoch  562000
#
# Epoch  563000
#
# Epoch  564000
#
# Saving model... Loss is:  tensor(0.0043, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  564000
# alpha: (goal 0.191  tensor([0.1769], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0472], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0274], grad_fn=<MulBackward0>)
#
# Epoch  565000
#
# Epoch  566000
#
# Epoch  567000
#
# Epoch  568000
#
# Saving model... Loss is:  tensor(0.0042, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  568000
# alpha: (goal 0.191  tensor([0.1801], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0479], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0277], grad_fn=<MulBackward0>)
#
# Epoch  569000
#
# Epoch  570000
#
# Epoch  571000
#
# Epoch  572000
#
# Saving model... Loss is:  tensor(0.0041, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  572000
# alpha: (goal 0.191  tensor([0.1826], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0485], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0280], grad_fn=<MulBackward0>)
#
# Epoch  573000
#
# Epoch  574000
#
# Epoch  575000
#
# Epoch  576000
#
# Saving model... Loss is:  tensor(0.0041, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  576000
# alpha: (goal 0.191  tensor([0.1839], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0488], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0281], grad_fn=<MulBackward0>)
#
# Epoch  577000
#
# Epoch  578000
#
# Epoch  579000
#
# Epoch  580000
#
# Saving model... Loss is:  tensor(0.0040, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  580000
# alpha: (goal 0.191  tensor([0.1783], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0478], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0276], grad_fn=<MulBackward0>)
#
# Epoch  581000
#
# Epoch  582000
#
# Epoch  583000
#
# Epoch  584000
#
# Saving model... Loss is:  tensor(0.0039, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  584000
# alpha: (goal 0.191  tensor([0.1786], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0477], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0276], grad_fn=<MulBackward0>)
#
# Epoch  585000
#
# Epoch  586000
#
# Epoch  587000
#
# Epoch  588000
#
# Saving model... Loss is:  tensor(0.0039, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  588000
# alpha: (goal 0.191  tensor([0.1798], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0480], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0276], grad_fn=<MulBackward0>)
#
# Epoch  589000
#
# Epoch  590000
#
# Epoch  591000
#
# Epoch  592000
#
# Saving model... Loss is:  tensor(0.0038, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  592000
# alpha: (goal 0.191  tensor([0.1809], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0482], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0277], grad_fn=<MulBackward0>)
#
# Epoch  593000
#
# Epoch  594000
#
# Epoch  595000
#
# Epoch  596000
#
# Saving model... Loss is:  tensor(0.0037, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  596000
# alpha: (goal 0.191  tensor([0.1820], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0484], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0278], grad_fn=<MulBackward0>)
#
# Epoch  597000
#
# Epoch  598000
#
# Epoch  599000
#
# Epoch  600000
#
# Saving model... Loss is:  tensor(0.0037, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  600000
# alpha: (goal 0.191  tensor([0.1831], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0486], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0278], grad_fn=<MulBackward0>)
#
# Epoch  601000
#
# Epoch  602000
#
# Epoch  603000
#
# Epoch  604000
#
# Saving model... Loss is:  tensor(0.0036, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  604000
# alpha: (goal 0.191  tensor([0.1857], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0491], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0281], grad_fn=<MulBackward0>)
#
# Epoch  605000
#
# Epoch  606000
#
# Epoch  607000
#
# Epoch  608000
#
# Saving model... Loss is:  tensor(0.0035, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  608000
# alpha: (goal 0.191  tensor([0.1865], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0494], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0283], grad_fn=<MulBackward0>)
#
# Epoch  609000
#
# Epoch  610000
#
# Epoch  611000
#
# Epoch  612000
#
# Saving model... Loss is:  tensor(0.0029, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  612000
# alpha: (goal 0.191  tensor([0.1854], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0492], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0281], grad_fn=<MulBackward0>)
#
# Epoch  613000
#
# Epoch  614000
#
# Epoch  615000
#
# Epoch  616000
#
# Saving model... Loss is:  tensor(0.0028, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  616000
# alpha: (goal 0.191  tensor([0.1860], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0494], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0282], grad_fn=<MulBackward0>)
#
# Epoch  617000
#
# Epoch  618000
#
# Epoch  619000
#
# Epoch  620000
#
# Saving model... Loss is:  tensor(0.0028, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  620000
# alpha: (goal 0.191  tensor([0.1868], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0497], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0283], grad_fn=<MulBackward0>)
#
# Epoch  621000
#
# Epoch  622000
#
# Epoch  623000
#
# Epoch  624000
#
# Saving model... Loss is:  tensor(0.0027, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  624000
# alpha: (goal 0.191  tensor([0.1878], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0499], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0283], grad_fn=<MulBackward0>)
#
# Epoch  625000
#
# Epoch  626000
#
# Epoch  627000
#
# Epoch  628000
#
# Saving model... Loss is:  tensor(0.0027, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  628000
# alpha: (goal 0.191  tensor([0.1887], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0501], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0284], grad_fn=<MulBackward0>)
#
# Epoch  629000
#
# Epoch  630000
#
# Epoch  631000
#
# Epoch  632000
#
# Saving model... Loss is:  tensor(0.0027, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  632000
# alpha: (goal 0.191  tensor([0.1896], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0503], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0284], grad_fn=<MulBackward0>)
#
# Epoch  633000
#
# Epoch  634000
#
# Epoch  635000
#
# Epoch  636000
#
# Saving model... Loss is:  tensor(0.0026, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  636000
# alpha: (goal 0.191  tensor([0.1905], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0504], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0285], grad_fn=<MulBackward0>)
#
# Epoch  637000
#
# Epoch  638000
#
# Epoch  639000
#
# Epoch  640000
#
# Saving model... Loss is:  tensor(0.0026, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  640000
# alpha: (goal 0.191  tensor([0.1915], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0506], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0285], grad_fn=<MulBackward0>)
#
# Epoch  641000
#
# Epoch  642000
#
# Epoch  643000
#
# Epoch  644000
#
# Saving model... Loss is:  tensor(0.0025, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  644000
# alpha: (goal 0.191  tensor([0.1924], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0508], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0286], grad_fn=<MulBackward0>)
#
# Epoch  645000
#
# Epoch  646000
#
# Epoch  647000
#
# Epoch  648000
#
# Saving model... Loss is:  tensor(0.0025, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  648000
# alpha: (goal 0.191  tensor([0.1934], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0509], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0286], grad_fn=<MulBackward0>)
#
# Epoch  649000
#
# Epoch  650000
#
# Epoch  651000
#
# Epoch  652000
#
# Saving model... Loss is:  tensor(0.0025, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  652000
# alpha: (goal 0.191  tensor([0.1943], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0511], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0287], grad_fn=<MulBackward0>)
#
# Epoch  653000
#
# Epoch  654000
#
# Epoch  655000
#
# Epoch  656000
#
# Saving model... Loss is:  tensor(0.0024, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  656000
# alpha: (goal 0.191  tensor([0.1953], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0513], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0287], grad_fn=<MulBackward0>)
#
# Epoch  657000
#
# Epoch  658000
#
# Epoch  659000
#
# Epoch  660000
#
# Saving model... Loss is:  tensor(0.0024, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  660000
# alpha: (goal 0.191  tensor([0.1962], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0514], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0287], grad_fn=<MulBackward0>)
#
# Epoch  661000
#
# Epoch  662000
#
# Epoch  663000
#
# Epoch  664000
#
# Saving model... Loss is:  tensor(0.0024, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  664000
# alpha: (goal 0.191  tensor([0.1972], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0515], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0288], grad_fn=<MulBackward0>)
#
# Epoch  665000
#
# Epoch  666000
#
# Epoch  667000
#
# Epoch  668000
#
# Saving model... Loss is:  tensor(0.0024, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  668000
# alpha: (goal 0.191  tensor([0.1981], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0517], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0288], grad_fn=<MulBackward0>)
#
# Epoch  669000
#
# Epoch  670000
#
# Epoch  671000
#
# Epoch  672000
#
# Saving model... Loss is:  tensor(0.0023, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  672000
# alpha: (goal 0.191  tensor([0.1990], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0518], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0289], grad_fn=<MulBackward0>)
#
# Epoch  673000
#
# Epoch  674000
#
# Epoch  675000
#
# Epoch  676000
#
# Saving model... Loss is:  tensor(0.0023, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  676000
# alpha: (goal 0.191  tensor([0.1999], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0520], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0289], grad_fn=<MulBackward0>)
#
# Epoch  677000
#
# Epoch  678000
#
# Epoch  679000
#
# Epoch  680000
#
# Saving model... Loss is:  tensor(0.0023, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  680000
# alpha: (goal 0.191  tensor([0.2008], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0521], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0289], grad_fn=<MulBackward0>)
#
# Epoch  681000
#
# Epoch  682000
#
# Epoch  683000
#
# Epoch  684000
#
# Saving model... Loss is:  tensor(0.0023, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  684000
# alpha: (goal 0.191  tensor([0.2016], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0522], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0290], grad_fn=<MulBackward0>)
#
# Epoch  685000
#
# Epoch  686000
#
# Epoch  687000
#
# Epoch  688000
#
# Saving model... Loss is:  tensor(0.0023, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  688000
# alpha: (goal 0.191  tensor([0.2025], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0523], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0290], grad_fn=<MulBackward0>)
#
# Epoch  689000
#
# Epoch  690000
#
# Epoch  691000
#
# Epoch  692000
#
# Saving model... Loss is:  tensor(0.0023, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  692000
# alpha: (goal 0.191  tensor([0.2032], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0525], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0290], grad_fn=<MulBackward0>)
#
# Epoch  693000
#
# Epoch  694000
#
# Epoch  695000
#
# Epoch  696000
#
# Saving model... Loss is:  tensor(0.0022, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  696000
# alpha: (goal 0.191  tensor([0.2040], grad_fn=<MulBackward0>)
# beta: (goal 0.05  tensor([0.0526], grad_fn=<MulBackward0>)
# gamma: (goal 0.0294  tensor([0.0291], grad_fn=<MulBackward0>)
#
# Epoch  697000
#
# Epoch  698000
#
# Epoch  699000
# CPU times: user 35min 22s, sys: 8.05 s, total: 35min 30s
# Wall time: 35min 35s

# %%
plt.plot(dinn.losses[300000:], color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss'),
# Out:
# (Text(0, 0.5, 'Loss'),)

# %%
fig = plt.figure(figsize=(12,12))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')


ax.plot(sidr_data[0], sidr_data[1], 'pink', alpha=0.5, lw=2, label='Susceptible')
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax.plot(sidr_data[0], sidr_data[2], 'violet', alpha=0.5, lw=2, label='Infected')
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax.plot(sidr_data[0], sidr_data[3], 'darkgreen', alpha=0.5, lw=2, label='Dead')
ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax.plot(sidr_data[0], sidr_data[4], 'blue', alpha=0.5, lw=2, label='Recovered')
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='black', lw=0.2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('itswhite.pdf')
plt.show()

# %%
#calculate relative MSE loss
import math
import numpy as np

S_total_loss = 0
S_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0
t = np.linspace(0, 500, 100) 

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S_pred_list[0].detach().numpy()[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2
  I_value = sidr_data[2][timestep] - I_pred_list[0].detach().numpy()[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[2][timestep])**2
  D_value = sidr_data[3][timestep] - D_pred_list[0].detach().numpy()[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[3][timestep])**2
  R_value = sidr_data[4][timestep] - R_pred_list[0].detach().numpy()[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[4][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S_total_loss: ', S_total_loss)
print('I_total_loss: ', I_total_loss)
print('D_total_loss: ', D_total_loss)
print('R_total_loss: ', R_total_loss)
# Out:
# S_total_loss:  0.030188054358057978
# I_total_loss:  0.10960784078915856
# D_total_loss:  0.027577180063967678
# R_total_loss:  0.027579815296883674

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial conditions
N = 59e6

S0 = N - 1
I0 = 1
D0 = 0
R0 = 0
# A grid of time points (in days)
t = np.linspace(0, 500, 100) 

#parameters
alpha = dinn.alpha
beta = dinn.beta
gamma = dinn.gamma

# The SIR model differential equations.
def deriv(y, t, alpha, betta, gamma):
    S, I, D, R = y
    dSdt = - (alpha / N) * S * I
    dIdt = (alpha / N) * S * I - beta * I - gamma * I 
    dDdt = gamma * I
    dRdt = beta * I

    return dSdt, dIdt, dDdt, dRdt


# Initial conditions vector
y0 = S0, I0, D0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(alpha, beta, gamma))
S, I, D, R = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(t, sidr_data[1], 'dodgerblue', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, I, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.plot(t, sidr_data[2], 'gold', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, D, 'red', alpha=0.5, lw=2, label='Learnable Param Dead', linestyle='dashed')
ax.plot(t, sidr_data[3], 'salmon', alpha=0.5, lw=2, label='Dead')

ax.plot(t, R, 'blue', alpha=0.5, lw=2, label='Learnable Param Recovered', linestyle='dashed')
ax.plot(t, sidr_data[4], 'wheat', alpha=0.5, lw=2, label='Recovered')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#calculate relative MSE loss
import math

S_total_loss = 0
S_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2
  I_value = sidr_data[2][timestep] - I[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[2][timestep])**2
  D_value = sidr_data[3][timestep] - D[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[3][timestep])**2
  R_value = sidr_data[4][timestep] - R[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[4][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S_total_loss: ', S_total_loss)
print('I_total_loss: ', I_total_loss)
print('D_total_loss: ', D_total_loss)
print('R_total_loss: ', R_total_loss)
# Out:
# S_total_loss:  0.13210409431498737
# I_total_loss:  0.5198289466071272
# D_total_loss:  0.08858141134764667
# R_total_loss:  0.11172515679895935
