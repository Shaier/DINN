# %% [markdown]
# # Paper: Modelling the COVID-19 epidemic and implementation of population-wide interventions in Italy

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %% [markdown]
# # Parameters:
#
# # 46 days:
# # if t < 4
# alpha = 0.570
# beta = 0.011
# gamma = 0.456
# delta = 0.011
# epsilon = 0.171
# zeta = 0.125
# lambdda = 0.034
# eta = 0.125
# rho = 0.034
# mu = 0.017
# kappa = 0.017
# theta = 0.371
# nu = 0.027
# xi = 0.017
# sigma = 0.017
# tao = 0.01
#
# # if  4 <= t < 12
# alpha = 0.422
# beta = 0.0057
# gamma = 0.285
# delta = 0.0057
# epsilon = 0.171
# zeta = 0.125
# lambdda = 0.034
# eta = 0.125
# rho = 0.034
# mu = 0.017
# kappa = 0.017
# theta = 0.371
# nu = 0.027
# xi = 0.017
# sigma = 0.017
# tao = 0.01
#
# # if  12 <= t < 22
# alpha = 0.422
# beta = 0.0057
# gamma = 0.285
# delta = 0.0057
# epsilon = 0.143
# zeta = 0.125
# lambdda = 0.034
# eta = 0.125
# rho = 0.034
# mu = 0.017
# kappa = 0.017
# theta = 0.371
# nu = 0.027
# xi = 0.017
# sigma = 0.017
# tao = 0.01
#
# # if  22 <= t < 28
# alpha = 0.360
# beta = 0.005
# gamma = 0.2
# delta = 0.005
# epsilon = 0.143
# zeta = 0.034
# lambdda = 0.08
# eta = 0.034
# rho = 0.017
# mu = 0.008
# kappa = 0.017
# theta = 0.371
# nu = 0.015
# xi = 0.017
# sigma = 0.017
# tao = 0.01
#
# # if  28 <= t < 38
# alpha = 0.210
# beta = 0.005
# gamma = 0.110
# delta = 0.005
# epsilon = 0.143
# zeta = 0.034
# lambdda = 0.08
# eta = 0.034
# rho = 0.017
# mu = 0.008
# kappa = 0.017
# theta = 0.371
# nu = 0.015
# xi = 0.017
# sigma = 0.017
# tao = 0.01
#
#
# # if  38 <= t < 50
# alpha = 0.210
# beta = 0.005
# gamma = 0.110
# delta = 0.005
# epsilon = 0.200
# zeta = 0.025
# lambdda = 0.08
# eta = 0.025
# rho = 0.020
# mu = 0.008
# kappa = 0.020
# theta = 0.371
# nu = 0.015
# xi = 0.020
# sigma = 0.010
# tao = 0.01
#
# # if  50 <= t
# alpha = 0.105
# beta = 0.005
# gamma = 0.110
# delta = 0.005
# epsilon = 0.200
# zeta = 0.025
# lambdda = 0.08
# eta = 0.025
# rho = 0.020
# mu = 0.008
# kappa = 0.020
# theta = 0.371
# nu = 0.015
# xi = 0.020
# sigma = 0.010
# tao = 0.01

# %%
#initial conditions
I0 = 200/60e6
D0 = 20/60e6
A0 = 1/60e6
R0 = 2/60e6
T0 = 0
H0 = 0
E0 = 0
S0 = 1 - I0 - D0 - A0 - R0 - T0 - H0 - E0

# A grid of time points (in days)
#t = np.linspace(0, 350, 351) 
t = np.linspace(0, 100, 100) 

# The SIR model differential equations.
def deriv(y, t):
    if t < 4:
        alpha = 0.570
        beta = 0.011
        gamma = 0.456
        delta = 0.011
        epsilon = 0.171
        zeta = 0.125
        lambdda = 0.034
        eta = 0.125
        rho = 0.034
        mu = 0.017
        kappa = 0.017
        theta = 0.371
        nu = 0.027
        xi = 0.017
        sigma = 0.017
        tao = 0.01

    if  4 <= t < 12:
        alpha = 0.422
        beta = 0.0057
        gamma = 0.285
        delta = 0.0057
        epsilon = 0.171
        zeta = 0.125
        lambdda = 0.034
        eta = 0.125
        rho = 0.034
        mu = 0.017
        kappa = 0.017
        theta = 0.371
        nu = 0.027
        xi = 0.017
        sigma = 0.017
        tao = 0.01

    if  12 <= t < 22:
        alpha = 0.422
        beta = 0.0057
        gamma = 0.285
        delta = 0.0057
        epsilon = 0.143
        zeta = 0.125
        lambdda = 0.034
        eta = 0.125
        rho = 0.034
        mu = 0.017
        kappa = 0.017
        theta = 0.371
        nu = 0.027
        xi = 0.017
        sigma = 0.017
        tao = 0.01

    if  22 <= t < 28:
        alpha = 0.360
        beta = 0.005
        gamma = 0.2
        delta = 0.005
        epsilon = 0.143
        zeta = 0.034
        lambdda = 0.08
        eta = 0.034
        rho = 0.017
        mu = 0.008
        kappa = 0.017
        theta = 0.371
        nu = 0.015
        xi = 0.017
        sigma = 0.017
        tao = 0.01

    if  28 <= t < 38:
        alpha = 0.210
        beta = 0.005
        gamma = 0.110
        delta = 0.005
        epsilon = 0.143
        zeta = 0.034
        lambdda = 0.08
        eta = 0.034
        rho = 0.017
        mu = 0.008
        kappa = 0.017
        theta = 0.371
        nu = 0.015
        xi = 0.017
        sigma = 0.017
        tao = 0.01


    if  38 <= t < 50:
        alpha = 0.210
        beta = 0.005
        gamma = 0.110
        delta = 0.005
        epsilon = 0.200
        zeta = 0.025
        lambdda = 0.08
        eta = 0.025
        rho = 0.020
        mu = 0.008
        kappa = 0.020
        theta = 0.371
        nu = 0.015
        xi = 0.020
        sigma = 0.010
        tao = 0.01

    if  50 <= t:
        alpha = 0.105
        beta = 0.005
        gamma = 0.110
        delta = 0.005
        epsilon = 0.200
        zeta = 0.025
        lambdda = 0.08
        eta = 0.025
        rho = 0.020
        mu = 0.008
        kappa = 0.020
        theta = 0.371
        nu = 0.015
        xi = 0.020
        sigma = 0.010
        tao = 0.01

    I, D, A, R, T, H, E, S = y
    dSdt = -S * (alpha * I + beta * D + gamma * A + delta * R)
    dIdt = S * (alpha * I + beta * D + gamma * A + delta * R) - (epsilon + zeta + lambdda) * I
    dDdt = epsilon * I - (eta + rho) * D
    dAdt = zeta * I - (theta + mu + kappa) * A 
    dRdt = eta * D + theta * A - (nu + xi) * R
    dTdt = mu * A + nu * R - (sigma + tao) * T
    dHdt = lambdda * I + rho * D + kappa * A + xi * R + sigma * T
    dEdt = tao * T

    return dIdt, dDdt, dAdt, dRdt, dTdt, dHdt, dEdt, dSdt

# Initial conditions vector
y0 = I0, D0, A0, R0, T0, H0, E0, S0

# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t)
I, D, A, R, T, H, E, S = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, I, 'violet', alpha=0.5, lw=2, label='Infected', linestyle='dashed')
ax.plot(t, D, 'darkgreen', alpha=0.5, lw=2, label='Diagnosed', linestyle='dashed')
ax.plot(t, A, 'red', alpha=0.5, lw=2, label='Ailling', linestyle='dashed')
ax.plot(t, R, 'blue', alpha=0.5, lw=2, label='Recognized', linestyle='dashed')
ax.plot(t, T, 'purple', alpha=0.5, lw=2, label='Threatened', linestyle='dashed')
#ax.plot(t, H, 'yellow', alpha=0.5, lw=2, label='Healed', linestyle='dashed')
ax.plot(t, E, 'black', alpha=0.5, lw=2, label='Extinct', linestyle='dashed')
#ax.plot(t, S, 'pink', alpha=0.5, lw=2, label='Susceptible', linestyle='dashed')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
t
# Out:
# array([  0.        ,   1.01010101,   2.02020202,   3.03030303,
#          4.04040404,   5.05050505,   6.06060606,   7.07070707,
#          8.08080808,   9.09090909,  10.1010101 ,  11.11111111,
#         12.12121212,  13.13131313,  14.14141414,  15.15151515,
#         16.16161616,  17.17171717,  18.18181818,  19.19191919,
#         20.2020202 ,  21.21212121,  22.22222222,  23.23232323,
#         24.24242424,  25.25252525,  26.26262626,  27.27272727,
#         28.28282828,  29.29292929,  30.3030303 ,  31.31313131,
#         32.32323232,  33.33333333,  34.34343434,  35.35353535,
#         36.36363636,  37.37373737,  38.38383838,  39.39393939,
#         40.4040404 ,  41.41414141,  42.42424242,  43.43434343,
#         44.44444444,  45.45454545,  46.46464646,  47.47474747,
#         48.48484848,  49.49494949,  50.50505051,  51.51515152,
#         52.52525253,  53.53535354,  54.54545455,  55.55555556,
#         56.56565657,  57.57575758,  58.58585859,  59.5959596 ,
#         60.60606061,  61.61616162,  62.62626263,  63.63636364,
#         64.64646465,  65.65656566,  66.66666667,  67.67676768,
#         68.68686869,  69.6969697 ,  70.70707071,  71.71717172,
#         72.72727273,  73.73737374,  74.74747475,  75.75757576,
#         76.76767677,  77.77777778,  78.78787879,  79.7979798 ,
#         80.80808081,  81.81818182,  82.82828283,  83.83838384,
#         84.84848485,  85.85858586,  86.86868687,  87.87878788,
#         88.88888889,  89.8989899 ,  90.90909091,  91.91919192,
#         92.92929293,  93.93939394,  94.94949495,  95.95959596,
#         96.96969697,  97.97979798,  98.98989899, 100.        ])

# %%
#save to csv file
a = np.asarray([t, S, I, D, A, R, T, H, E ]) 

#np.savetxt("tSIDARTHE_data.csv", a, delimiter=",")

# %%
#getting same number of points from each bin
t_complete = []
I_complete = []
D_complete = []
A_complete = []
R_complete = []
T_complete = []
H_complete = []
E_complete = []
S_complete = []

# %%
#initial conditions
I0 = 200/60e6
D0 = 20/60e6
A0 = 1/60e6
R0 = 2/60e6
T0 = 0
H0 = 0
E0 = 0
S0 = 1 - I0 - D0 - A0 - R0 - T0 - H0 - E0

# A grid of time points (in days)
t = np.linspace(0, 80, 100) 
#t = np.linspace(51.9, 71.9, 3) 

# The SIR model differential equations.
def deriv(y, t):
    if t < 4:
        alpha = 0.570
        beta = 0.011
        gamma = 0.456
        delta = 0.011
        epsilon = 0.171
        zeta = 0.125
        lambdda = 0.034
        eta = 0.125
        rho = 0.034
        mu = 0.017
        kappa = 0.017
        theta = 0.371
        nu = 0.027
        xi = 0.017
        sigma = 0.017
        tao = 0.01

    if  4 <= t < 12:
        alpha = 0.422
        beta = 0.0057
        gamma = 0.285
        delta = 0.0057
        epsilon = 0.171
        zeta = 0.125
        lambdda = 0.034
        eta = 0.125
        rho = 0.034
        mu = 0.017
        kappa = 0.017
        theta = 0.371
        nu = 0.027
        xi = 0.017
        sigma = 0.017
        tao = 0.01

    if  12 <= t < 22:
        alpha = 0.422
        beta = 0.0057
        gamma = 0.285
        delta = 0.0057
        epsilon = 0.143
        zeta = 0.125
        lambdda = 0.034
        eta = 0.125
        rho = 0.034
        mu = 0.017
        kappa = 0.017
        theta = 0.371
        nu = 0.027
        xi = 0.017
        sigma = 0.017
        tao = 0.01

    if  22 <= t < 28:
        alpha = 0.360
        beta = 0.005
        gamma = 0.2
        delta = 0.005
        epsilon = 0.143
        zeta = 0.034
        lambdda = 0.08
        eta = 0.034
        rho = 0.017
        mu = 0.008
        kappa = 0.017
        theta = 0.371
        nu = 0.015
        xi = 0.017
        sigma = 0.017
        tao = 0.01

    if  28 <= t < 38:
        alpha = 0.210
        beta = 0.005
        gamma = 0.110
        delta = 0.005
        epsilon = 0.143
        zeta = 0.034
        lambdda = 0.08
        eta = 0.034
        rho = 0.017
        mu = 0.008
        kappa = 0.017
        theta = 0.371
        nu = 0.015
        xi = 0.017
        sigma = 0.017
        tao = 0.01


    if  38 <= t < 50:
        alpha = 0.210
        beta = 0.005
        gamma = 0.110
        delta = 0.005
        epsilon = 0.200
        zeta = 0.025
        lambdda = 0.08
        eta = 0.025
        rho = 0.020
        mu = 0.008
        kappa = 0.020
        theta = 0.371
        nu = 0.015
        xi = 0.020
        sigma = 0.010
        tao = 0.01

    if  50 <= t:
        alpha = 0.105
        beta = 0.005
        gamma = 0.110
        delta = 0.005
        epsilon = 0.200
        zeta = 0.025
        lambdda = 0.08
        eta = 0.025
        rho = 0.020
        mu = 0.008
        kappa = 0.020
        theta = 0.371
        nu = 0.015
        xi = 0.020
        sigma = 0.010
        tao = 0.01

    I, D, A, R, T, H, E, S = y
    dSdt = -S * (alpha * I + beta * D + gamma * A + delta * R)
    dIdt = S * (alpha * I + beta * D + gamma * A + delta * R) - (epsilon + zeta + lambdda) * I
    dDdt = epsilon * I - (eta + rho) * D
    dAdt = zeta * I - (theta + mu + kappa) * A 
    dRdt = eta * D + theta * A - (nu + xi) * R
    dTdt = mu * A + nu * R - (sigma + tao) * T
    dHdt = lambdda * I + rho * D + kappa * A + xi * R + sigma * T
    dEdt = tao * T

    return dIdt, dDdt, dAdt, dRdt, dTdt, dHdt, dEdt, dSdt

# Initial conditions vector
y0 = I0, D0, A0, R0, T0, H0, E0, S0

# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t)
I, D, A, R, T, H, E, S = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, I, 'violet', alpha=0.5, lw=2, label='Infected', linestyle='dashed')
ax.plot(t, D, 'darkgreen', alpha=0.5, lw=2, label='Diagnosed', linestyle='dashed')
ax.plot(t, A, 'red', alpha=0.5, lw=2, label='Ailling', linestyle='dashed')
ax.plot(t, R, 'blue', alpha=0.5, lw=2, label='Recognized', linestyle='dashed')
ax.plot(t, T, 'purple', alpha=0.5, lw=2, label='Threatened', linestyle='dashed')
#ax.plot(t, H, 'yellow', alpha=0.5, lw=2, label='Healed', linestyle='dashed')
ax.plot(t, E, 'black', alpha=0.5, lw=2, label='Extinct', linestyle='dashed')
#ax.plot(t, S, 'pink', alpha=0.5, lw=2, label='Susceptible', linestyle='dashed')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()


t_complete = np.append(t_complete, t, 0)
S_complete = np.append(S_complete, S, 0)
I_complete = np.append(I_complete, I, 0)
D_complete = np.append(D_complete, D, 0)
A_complete = np.append(A_complete, A, 0)
R_complete = np.append(R_complete, R, 0)
T_complete = np.append(T_complete, T, 0)
H_complete = np.append(H_complete, H, 0)
E_complete = np.append(E_complete, E, 0)

# %%
# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t_complete, I_complete, 'violet', alpha=0.5, lw=2, label='Infected', linestyle='dashed')
ax.plot(t_complete, D_complete, 'darkgreen', alpha=0.5, lw=2, label='Diagnosed', linestyle='dashed')
ax.plot(t_complete, A_complete, 'red', alpha=0.5, lw=2, label='Ailling', linestyle='dashed')
ax.plot(t_complete, R_complete, 'blue', alpha=0.5, lw=2, label='Recognized', linestyle='dashed')
ax.plot(t_complete, T_complete, 'purple', alpha=0.5, lw=2, label='Threatened', linestyle='dashed')
#ax.plot(t, H, 'yellow', alpha=0.5, lw=2, label='Healed', linestyle='dashed')
ax.plot(t_complete, E_complete, 'black', alpha=0.5, lw=2, label='Extinct', linestyle='dashed')
#ax.plot(t, S, 'pink', alpha=0.5, lw=2, label='Susceptible', linestyle='dashed')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()
