# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import math

cholera_data = genfromtxt('cholera.csv', delimiter=',') #in the form of [t, S,I,B]

torch.manual_seed(1234)

# %%
# %%time

PATH = 'cholera' 

class DINN(nn.Module):
    def __init__(self, t, S_data, I_data, B_data):
        super(DINN, self).__init__()
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.I = torch.tensor(I_data)
        self.B = torch.tensor(B_data)
        self.H = torch.tensor(1000)

        self.losses = [] #keep the losses
        self.save = 3 #which file to save to

        #learnable parameters
        self.n_tilda = torch.tensor(0.0001)
        self.a_tilda = torch.tensor(1)
        self.K_tilda = torch.tensor(106)
        self.r_tilda = torch.tensor(0.2)
        self.e_tilda = torch.tensor(10)
        #self.lambdda_tilda = torch.tensor(self.B / (self.K_tilda + self.B))

        #matrices (x3 for S, B, I) for the gradients
        self.m1 = torch.zeros((len(self.t), 3)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 3)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 3)); self.m3[:, 2] = 1

        #values for norm
        self.S_max = max(self.S)
        self.B_max = max(self.B)
        self.I_max = max(self.I)
        self.S_min = min(self.S)
        self.B_min = min(self.B)
        self.I_min = min(self.I)

        #normalize 
        self.S_hat = (self.S - self.S_min)/(self.S_max - self.S_min)
        self.B_hat = (self.B - self.B_min)/(self.B_max - self.B_min)
        self.I_hat = (self.I - self.I_min)/(self.I_max - self.I_min)

        #NN
        self.net_cholera = self.Net_cholera()
        self.params = list(self.net_cholera.parameters())
        self.params.extend(list([self.n_tilda ,self.a_tilda ,self.K_tilda ,self.r_tilda ,self.e_tilda]))

        
    #force parameters to be in a range
    @property
    def n(self):
        return self.n_tilda
    @property
    def a(self):
        return self.a_tilda
    @property
    def K(self):
        return self.K_tilda
    @property
    def r(self):
        return self.r_tilda
    @property
    def e(self):
        return self.e_tilda
    # @property
    # def lambdda(self):
    #     return self.lambdda_tilda

    #nets
    class Net_cholera(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_cholera, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 3) #outputs S, B, I

        def forward(self, t):
            cholera=F.relu(self.fc1(t))
            cholera=F.relu(self.fc2(cholera))
            cholera=F.relu(self.fc3(cholera))
            cholera=F.relu(self.fc4(cholera))
            cholera=F.relu(self.fc5(cholera))
            cholera=F.relu(self.fc6(cholera))
            cholera=F.relu(self.fc7(cholera))
            cholera=F.relu(self.fc8(cholera))
            cholera=self.out(cholera)
            return cholera    

    def net_f(self, t_batch):       

        cholera_hat = self.net_cholera(t_batch)

        S_hat, B_hat, I_hat = cholera_hat[:,0], cholera_hat[:,1], cholera_hat[:,2]

        #S_hat
        cholera_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #B_hat
        cholera_hat.backward(self.m2, retain_graph=True)
        B_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_hat
        cholera_hat.backward(self.m3, retain_graph=True)
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        B = self.B_min + (self.B_max - self.B_min) * B_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
     
        #equations
        lambdda = 1 #B / (self.K + B)

        f1_hat = S_hat_t - (self.n * (self.H - S) - self.a * lambdda * S) / (self.S_max - self.S_min) 
        f2_hat = B_hat_t - (B * (-0.33) + self.e * I) / (self.B_max - self.B_min) 
        f3_hat = I_hat_t - (self.a * lambdda * S - self.r * I) / (self.I_max - self.I_min) 

        return f1_hat, f2_hat, f3_hat, S_hat, B_hat, I_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        loss = checkpoint['loss']
        self.losses = checkpoint['losses']
        print('loaded previous loss: ', loss)
      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        B_pred_list = []
        I_pred_list = []

        f1_hat, f2_hat, f3_hat, S_hat_pred, B_hat_pred, I_hat_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_hat_pred)
        B_pred_list.append(self.B_min + (self.B_max - self.B_min) * B_hat_pred)
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_hat_pred)

        loss = (
              torch.mean(torch.square(self.S_hat - S_hat_pred)) + torch.mean(torch.square(self.B_hat - B_hat_pred)) + 
              torch.mean(torch.square(self.I_hat - I_hat_pred)) +
              torch.mean(torch.square(f1_hat)) + torch.mean(torch.square(f2_hat)) +
              torch.mean(torch.square(f3_hat))
               )

        loss.backward()

        self.optimizer.step()
        self.scheduler.step() 
        #self.scheduler.step(loss) 

        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)

        #loss + model parameters update
        if epoch % 4000 == 0:
          #checkpoint save every 1000 epochs if the loss is lower
          print('\nSaving model... Loss is: ', loss)
          torch.save({
              'epoch': epoch,
              'model': self.state_dict(),
              'optimizer_state_dict': self.optimizer.state_dict(),
              'scheduler': self.scheduler.state_dict(),
              'loss': loss,
              'losses': self.losses,
              }, PATH + str(self.save)+'.pt')
          if self.save % 2 > 0: #its on 3
            self.save = 2 #change to 2
          else: #its on 2
            self.save = 3 #change to 3

          print('epoch: ', epoch)
          # print('alpha1: (goal 1)', self.alpha1)
          # print('\nalpha2: (goal 0)', self.alpha2)
          # print('\nbeta: (goal 0.0075): ', self.beta)
          # print('\nmu (goal 5): ', self.mu)
          # print('\nu: (goal 0.515151515): ', self.u)
          # print('\ntao (goal 0.58): ', self.tao)
          print('#################################')
        
      #plot
      plt.plot(self.losses, color = 'teal')
      plt.xlabel('Epochs')
      plt.ylabel('Loss')
      return S_pred_list, B_pred_list, I_pred_list
# Out:
# CPU times: user 56 µs, sys: 1e+03 ns, total: 57 µs
# Wall time: 59.8 µs

# %%
# %%time

#this worked best
dinn = DINN(cholera_data[0], cholera_data[1], cholera_data[2], cholera_data[3])

learning_rate = 1e-4
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(dinn.optimizer, factor=0.9, patience = 5000, verbose=True)
#scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=100, mode="triangular2", cycle_momentum=False)
scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-7, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)

dinn.scheduler = scheduler

try: 
  S_pred_list, B_pred_list, I_pred_list = dinn.train(1000000) #train
except EOFError:
  if dinn.save == 2:
    dinn.save = 3
    S_pred_list, B_pred_list, I_pred_list = dinn.train(1000000) #train
  elif dinn.save == 3:
    dinn.save = 2
    S_pred_list, B_pred_list, I_pred_list = dinn.train(1000000) #train
# Out:
# loat64, grad_fn=<AddBackward0>)
# epoch:  592000
# #################################
#
# Epoch  593000
#
# Epoch  594000
#
# Epoch  595000
#
# Epoch  596000
#
# Saving model... Loss is:  tensor(0.0784, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  596000
# #################################
#
# Epoch  597000
#
# Epoch  598000
#
# Epoch  599000
#
# Epoch  600000
#
# Saving model... Loss is:  tensor(0.0772, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  600000
# #################################
#
# Epoch  601000
#
# Epoch  602000
#
# Epoch  603000
#
# Epoch  604000
#
# Saving model... Loss is:  tensor(0.0761, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  604000
# #################################
#
# Epoch  605000
#
# Epoch  606000
#
# Epoch  607000
#
# Epoch  608000
#
# Saving model... Loss is:  tensor(0.0754, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  608000
# #################################
#
# Epoch  609000
#
# Epoch  610000
#
# Epoch  611000
#
# Epoch  612000
#
# Saving model... Loss is:  tensor(0.0744, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  612000
# #################################
#
# Epoch  613000
#
# Epoch  614000
#
# Epoch  615000
#
# Epoch  616000
#
# Saving model... Loss is:  tensor(0.0736, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  616000
# #################################
#
# Epoch  617000
#
# Epoch  618000
#
# Epoch  619000
#
# Epoch  620000
#
# Saving model... Loss is:  tensor(0.0727, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  620000
# #################################
#
# Epoch  621000
#
# Epoch  622000
#
# Epoch  623000
#
# Epoch  624000
#
# Saving model... Loss is:  tensor(0.0716, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  624000
# #################################
#
# Epoch  625000
#
# Epoch  626000
#
# Epoch  627000
#
# Epoch  628000
#
# Saving model... Loss is:  tensor(0.0709, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  628000
# #################################
#
# Epoch  629000
#
# Epoch  630000
#
# Epoch  631000
#
# Epoch  632000
#
# Saving model... Loss is:  tensor(0.0701, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  632000
# #################################
#
# Epoch  633000
#
# Epoch  634000
#
# Epoch  635000
#
# Epoch  636000
#
# Saving model... Loss is:  tensor(0.0693, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  636000
# #################################
#
# Epoch  637000
#
# Epoch  638000
#
# Epoch  639000
#
# Epoch  640000
#
# Saving model... Loss is:  tensor(0.0685, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  640000
# #################################
#
# Epoch  641000
#
# Epoch  642000
#
# Epoch  643000
#
# Epoch  644000
#
# Saving model... Loss is:  tensor(0.0678, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  644000
# #################################
#
# Epoch  645000
#
# Epoch  646000
#
# Epoch  647000
#
# Epoch  648000
#
# Saving model... Loss is:  tensor(0.0669, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  648000
# #################################
#
# Epoch  649000
#
# Epoch  650000
#
# Epoch  651000
#
# Epoch  652000
#
# Saving model... Loss is:  tensor(0.0660, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  652000
# #################################
#
# Epoch  653000
#
# Epoch  654000
#
# Epoch  655000
#
# Epoch  656000
#
# Saving model... Loss is:  tensor(0.0653, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  656000
# #################################
#
# Epoch  657000
#
# Epoch  658000
#
# Epoch  659000
#
# Epoch  660000
#
# Saving model... Loss is:  tensor(0.0643, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  660000
# #################################
#
# Epoch  661000
#
# Epoch  662000
#
# Epoch  663000
#
# Epoch  664000
#
# Saving model... Loss is:  tensor(0.0636, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  664000
# #################################
#
# Epoch  665000
#
# Epoch  666000
#
# Epoch  667000
#
# Epoch  668000
#
# Saving model... Loss is:  tensor(0.0629, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  668000
# #################################
#
# Epoch  669000
#
# Epoch  670000
#
# Epoch  671000
#
# Epoch  672000
#
# Saving model... Loss is:  tensor(0.0620, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  672000
# #################################
#
# Epoch  673000
#
# Epoch  674000
#
# Epoch  675000
#
# Epoch  676000
#
# Saving model... Loss is:  tensor(0.0615, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  676000
# #################################
#
# Epoch  677000
#
# Epoch  678000
#
# Epoch  679000
#
# Epoch  680000
#
# Saving model... Loss is:  tensor(0.0607, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  680000
# #################################
#
# Epoch  681000
#
# Epoch  682000
#
# Epoch  683000
#
# Epoch  684000
#
# Saving model... Loss is:  tensor(0.0602, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  684000
# #################################
#
# Epoch  685000
#
# Epoch  686000
#
# Epoch  687000
#
# Epoch  688000
#
# Saving model... Loss is:  tensor(0.0596, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  688000
# #################################
#
# Epoch  689000
#
# Epoch  690000
#
# Epoch  691000
#
# Epoch  692000
#
# Saving model... Loss is:  tensor(0.0592, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  692000
# #################################
#
# Epoch  693000
#
# Epoch  694000
#
# Epoch  695000
#
# Epoch  696000
#
# Saving model... Loss is:  tensor(0.0584, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  696000
# #################################
#
# Epoch  697000
#
# Epoch  698000
#
# Epoch  699000
#
# Epoch  700000
#
# Saving model... Loss is:  tensor(0.0576, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  700000
# #################################
#
# Epoch  701000
#
# Epoch  702000
#
# Epoch  703000
#
# Epoch  704000
#
# Saving model... Loss is:  tensor(0.0571, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  704000
# #################################
#
# Epoch  705000
#
# Epoch  706000
#
# Epoch  707000
#
# Epoch  708000
#
# Saving model... Loss is:  tensor(0.0565, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  708000
# #################################
#
# Epoch  709000
#
# Epoch  710000
#
# Epoch  711000
#
# Epoch  712000
#
# Saving model... Loss is:  tensor(0.0555, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  712000
# #################################
#
# Epoch  713000
#
# Epoch  714000
#
# Epoch  715000
#
# Epoch  716000
#
# Saving model... Loss is:  tensor(0.0551, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  716000
# #################################
#
# Epoch  717000
#
# Epoch  718000
#
# Epoch  719000
#
# Epoch  720000
#
# Saving model... Loss is:  tensor(0.0550, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  720000
# #################################
#
# Epoch  721000
#
# Epoch  722000
#
# Epoch  723000
#
# Epoch  724000
#
# Saving model... Loss is:  tensor(0.0545, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  724000
# #################################
#
# Epoch  725000
#
# Epoch  726000
#
# Epoch  727000
#
# Epoch  728000
#
# Saving model... Loss is:  tensor(0.0541, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  728000
# #################################
#
# Epoch  729000
#
# Epoch  730000
#
# Epoch  731000
#
# Epoch  732000
#
# Saving model... Loss is:  tensor(0.0537, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  732000
# #################################
#
# Epoch  733000
#
# Epoch  734000
#
# Epoch  735000
#
# Epoch  736000
#
# Saving model... Loss is:  tensor(0.0533, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  736000
# #################################
#
# Epoch  737000
#
# Epoch  738000
#
# Epoch  739000
#
# Epoch  740000
#
# Saving model... Loss is:  tensor(0.0529, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  740000
# #################################
#
# Epoch  741000
#
# Epoch  742000
#
# Epoch  743000
#
# Epoch  744000
#
# Saving model... Loss is:  tensor(0.0526, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  744000
# #################################
#
# Epoch  745000
#
# Epoch  746000
#
# Epoch  747000
#
# Epoch  748000
#
# Saving model... Loss is:  tensor(0.0528, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  748000
# #################################
#
# Epoch  749000
#
# Epoch  750000
#
# Epoch  751000
#
# Epoch  752000
#
# Saving model... Loss is:  tensor(0.0524, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  752000
# #################################
#
# Epoch  753000
#
# Epoch  754000
#
# Epoch  755000
#
# Epoch  756000
#
# Saving model... Loss is:  tensor(0.0519, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  756000
# #################################
#
# Epoch  757000
#
# Epoch  758000
#
# Epoch  759000
#
# Epoch  760000
#
# Saving model... Loss is:  tensor(0.0518, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  760000
# #################################
#
# Epoch  761000
#
# Epoch  762000
#
# Epoch  763000
#
# Epoch  764000
#
# Saving model... Loss is:  tensor(0.0513, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  764000
# #################################
#
# Epoch  765000
#
# Epoch  766000
#
# Epoch  767000
#
# Epoch  768000
#
# Saving model... Loss is:  tensor(0.0510, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  768000
# #################################
#
# Epoch  769000
#
# Epoch  770000
#
# Epoch  771000
#
# Epoch  772000
#
# Saving model... Loss is:  tensor(0.0497, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  772000
# #################################
#
# Epoch  773000
#
# Epoch  774000
#
# Epoch  775000
#
# Epoch  776000
#
# Saving model... Loss is:  tensor(0.0503, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  776000
# #################################
#
# Epoch  777000
#
# Epoch  778000
#
# Epoch  779000
#
# Epoch  780000
#
# Saving model... Loss is:  tensor(0.0500, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  780000
# #################################
#
# Epoch  781000
#
# Epoch  782000
#
# Epoch  783000
#
# Epoch  784000
#
# Saving model... Loss is:  tensor(0.0492, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  784000
# #################################
#
# Epoch  785000
#
# Epoch  786000
#
# Epoch  787000
#
# Epoch  788000
#
# Saving model... Loss is:  tensor(0.0500, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  788000
# #################################
#
# Epoch  789000
#
# Epoch  790000
#
# Epoch  791000
#
# Epoch  792000
#
# Saving model... Loss is:  tensor(0.0498, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  792000
# #################################
#
# Epoch  793000
#
# Epoch  794000
#
# Epoch  795000
#
# Epoch  796000
#
# Saving model... Loss is:  tensor(0.0490, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  796000
# #################################
#
# Epoch  797000
#
# Epoch  798000
#
# Epoch  799000
#
# Epoch  800000
#
# Saving model... Loss is:  tensor(0.0484, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  800000
# #################################
#
# Epoch  801000
#
# Epoch  802000
#
# Epoch  803000
#
# Epoch  804000
#
# Saving model... Loss is:  tensor(0.0498, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  804000
# #################################
#
# Epoch  805000
#
# Epoch  806000
#
# Epoch  807000
#
# Epoch  808000
#
# Saving model... Loss is:  tensor(0.0482, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  808000
# #################################
#
# Epoch  809000
#
# Epoch  810000
#
# Epoch  811000
#
# Epoch  812000
#
# Saving model... Loss is:  tensor(0.0482, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  812000
# #################################
#
# Epoch  813000
#
# Epoch  814000
#
# Epoch  815000
#
# Epoch  816000
#
# Saving model... Loss is:  tensor(0.0484, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  816000
# #################################
#
# Epoch  817000
#
# Epoch  818000
#
# Epoch  819000
#
# Epoch  820000
#
# Saving model... Loss is:  tensor(0.0481, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  820000
# #################################
#
# Epoch  821000
#
# Epoch  822000
#
# Epoch  823000
#
# Epoch  824000
#
# Saving model... Loss is:  tensor(0.0480, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  824000
# #################################
#
# Epoch  825000
#
# Epoch  826000
#
# Epoch  827000
#
# Epoch  828000
#
# Saving model... Loss is:  tensor(0.0478, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  828000
# #################################
#
# Epoch  829000
#
# Epoch  830000
#
# Epoch  831000
#
# Epoch  832000
#
# Saving model... Loss is:  tensor(0.0484, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  832000
# #################################
#
# Epoch  833000
#
# Epoch  834000
#
# Epoch  835000
#
# Epoch  836000
#
# Saving model... Loss is:  tensor(0.0491, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  836000
# #################################
#
# Epoch  837000
#
# Epoch  838000
#
# Epoch  839000
#
# Epoch  840000
#
# Saving model... Loss is:  tensor(0.0484, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  840000
# #################################
#
# Epoch  841000
#
# Epoch  842000
#
# Epoch  843000
#
# Epoch  844000
#
# Saving model... Loss is:  tensor(0.0486, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  844000
# #################################
#
# Epoch  845000
#
# Epoch  846000
#
# Epoch  847000
#
# Epoch  848000
#
# Saving model... Loss is:  tensor(0.0483, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  848000
# #################################
#
# Epoch  849000
#
# Epoch  850000
#
# Epoch  851000
#
# Epoch  852000
#
# Saving model... Loss is:  tensor(0.0474, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  852000
# #################################
#
# Epoch  853000
#
# Epoch  854000
#
# Epoch  855000
#
# Epoch  856000
#
# Saving model... Loss is:  tensor(0.0482, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  856000
# #################################
#
# Epoch  857000
#
# Epoch  858000
#
# Epoch  859000
#
# Epoch  860000
#
# Saving model... Loss is:  tensor(0.0473, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  860000
# #################################
#
# Epoch  861000
#
# Epoch  862000
#
# Epoch  863000
#
# Epoch  864000
#
# Saving model... Loss is:  tensor(0.0475, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  864000
# #################################
#
# Epoch  865000
#
# Epoch  866000
#
# Epoch  867000
#
# Epoch  868000
#
# Saving model... Loss is:  tensor(0.0483, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  868000
# #################################
#
# Epoch  869000
#
# Epoch  870000
#
# Epoch  871000
#
# Epoch  872000
#
# Saving model... Loss is:  tensor(0.0489, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  872000
# #################################
#
# Epoch  873000
#
# Epoch  874000
#
# Epoch  875000
#
# Epoch  876000
#
# Saving model... Loss is:  tensor(0.0482, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  876000
# #################################
#
# Epoch  877000
#
# Epoch  878000
#
# Epoch  879000
#
# Epoch  880000
#
# Saving model... Loss is:  tensor(0.0483, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  880000
# #################################
#
# Epoch  881000
#
# Epoch  882000
#
# Epoch  883000
#
# Epoch  884000
#
# Saving model... Loss is:  tensor(0.0477, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  884000
# #################################
#
# Epoch  885000
#
# Epoch  886000
#
# Epoch  887000
#
# Epoch  888000
#
# Saving model... Loss is:  tensor(0.0484, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  888000
# #################################
#
# Epoch  889000
#
# Epoch  890000
#
# Epoch  891000
#
# Epoch  892000
#
# Saving model... Loss is:  tensor(0.0476, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  892000
# #################################
#
# Epoch  893000
#
# Epoch  894000
#
# Epoch  895000
#
# Epoch  896000
#
# Saving model... Loss is:  tensor(0.0476, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  896000
# #################################
#
# Epoch  897000
#
# Epoch  898000
#
# Epoch  899000
#
# Epoch  900000
#
# Saving model... Loss is:  tensor(0.0482, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  900000
# #################################
#
# Epoch  901000
#
# Epoch  902000
#
# Epoch  903000
#
# Epoch  904000
#
# Saving model... Loss is:  tensor(0.0494, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  904000
# #################################
#
# Epoch  905000
#
# Epoch  906000
#
# Epoch  907000
#
# Epoch  908000
#
# Saving model... Loss is:  tensor(0.0489, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  908000
# #################################
#
# Epoch  909000
#
# Epoch  910000
#
# Epoch  911000
#
# Epoch  912000
#
# Saving model... Loss is:  tensor(0.0492, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  912000
# #################################
#
# Epoch  913000
#
# Epoch  914000
#
# Epoch  915000
#
# Epoch  916000
#
# Saving model... Loss is:  tensor(0.0482, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  916000
# #################################
#
# Epoch  917000
#
# Epoch  918000
#
# Epoch  919000
#
# Epoch  920000
#
# Saving model... Loss is:  tensor(0.0502, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  920000
# #################################
#
# Epoch  921000
#
# Epoch  922000
#
# Epoch  923000
#
# Epoch  924000
#
# Saving model... Loss is:  tensor(0.0500, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  924000
# #################################
#
# Epoch  925000
#
# Epoch  926000
#
# Epoch  927000
#
# Epoch  928000
#
# Saving model... Loss is:  tensor(0.0504, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  928000
# #################################
#
# Epoch  929000
#
# Epoch  930000
#
# Epoch  931000
#
# Epoch  932000
#
# Saving model... Loss is:  tensor(0.0506, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  932000
# #################################
#
# Epoch  933000
#
# Epoch  934000
#
# Epoch  935000
#
# Epoch  936000
#
# Saving model... Loss is:  tensor(0.0528, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  936000
# #################################
#
# Epoch  937000
#
# Epoch  938000
#
# Epoch  939000
#
# Epoch  940000
#
# Saving model... Loss is:  tensor(0.0533, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  940000
# #################################
#
# Epoch  941000
#
# Epoch  942000
#
# Epoch  943000
#
# Epoch  944000
#
# Saving model... Loss is:  tensor(0.0530, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  944000
# #################################
#
# Epoch  945000
#
# Epoch  946000
#
# Epoch  947000
#
# Epoch  948000
#
# Saving model... Loss is:  tensor(0.0534, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  948000
# #################################
#
# Epoch  949000
#
# Epoch  950000
#
# Epoch  951000
#
# Epoch  952000
#
# Saving model... Loss is:  tensor(0.0534, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  952000
# #################################
#
# Epoch  953000
#
# Epoch  954000
#
# Epoch  955000
#
# Epoch  956000
#
# Saving model... Loss is:  tensor(0.0533, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  956000
# #################################
#
# Epoch  957000
#
# Epoch  958000
#
# Epoch  959000
#
# Epoch  960000
#
# Saving model... Loss is:  tensor(0.0529, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  960000
# #################################
#
# Epoch  961000
#
# Epoch  962000
#
# Epoch  963000
#
# Epoch  964000
#
# Saving model... Loss is:  tensor(0.0536, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  964000
# #################################
#
# Epoch  965000
#
# Epoch  966000
#
# Epoch  967000
#
# Epoch  968000
#
# Saving model... Loss is:  tensor(0.0542, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  968000
# #################################
#
# Epoch  969000
#
# Epoch  970000
#
# Epoch  971000
#
# Epoch  972000
#
# Saving model... Loss is:  tensor(0.0548, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  972000
# #################################
#
# Epoch  973000
#
# Epoch  974000
#
# Epoch  975000
#
# Epoch  976000
#
# Saving model... Loss is:  tensor(0.0557, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  976000
# #################################
#
# Epoch  977000
#
# Epoch  978000
#
# Epoch  979000
#
# Epoch  980000
#
# Saving model... Loss is:  tensor(0.0561, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  980000
# #################################
#
# Epoch  981000
#
# Epoch  982000
#
# Epoch  983000
#
# Epoch  984000
#
# Saving model... Loss is:  tensor(0.0579, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  984000
# #################################
#
# Epoch  985000
#
# Epoch  986000
#
# Epoch  987000
#
# Epoch  988000
#
# Saving model... Loss is:  tensor(0.0588, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  988000
# #################################
#
# Epoch  989000
#
# Epoch  990000
#
# Epoch  991000
#
# Epoch  992000
#
# Saving model... Loss is:  tensor(0.0581, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  992000
# #################################
#
# Epoch  993000
#
# Epoch  994000
#
# Epoch  995000
#
# Epoch  996000
#
# Saving model... Loss is:  tensor(0.0594, dtype=torch.float64, grad_fn=<AddBackward0>)
# epoch:  996000
# #################################
#
# Epoch  997000
#
# Epoch  998000
#
# Epoch  999000
# CPU times: user 46min 10s, sys: 9.38 s, total: 46min 19s
# Wall time: 46min 27s

# %%
plt.plot(dinn.losses[350000:], color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(cholera_data[0], cholera_data[1], 'pink', alpha=0.5, lw=2, label='S')
ax.plot(cholera_data[0], S_pred_list[0].detach().numpy(), 'navy', alpha=0.9, lw=2, label='S Prediction', linestyle='dashed')

# ax.plot(cholera_data[0], cholera_data[2], 'darkgreen', alpha=0.5, lw=2, label='I')
# ax.plot(cholera_data[0], I_pred_list[0].detach().numpy(), 'gold', alpha=0.9, lw=2, label='I Prediction', linestyle='dashed')

# ax.plot(cholera_data[0], cholera_data[3], 'violet', alpha=0.5, lw=2, label='B')
# ax.plot(cholera_data[0], B_pred_list[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='B Prediction', linestyle='dashed')

ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
#ax.set_ylim([-1,50])
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
-print('alpha1: (goal 1)', round(dinn.alpha1.item(),2))
print('\nalpha2: (goal 0)', round(dinn.alpha2.item(),2))
print('\nbeta: (goal 0.0075): ', round(dinn.beta.item(),4))
print('\nmu (goal 5): ', round(dinn.mu.item(),2))
print('\nu: (goal 0.515151515): ', round(dinn.u.item(),2))
print('\ntao (goal 0.58): ', round(dinn.tao.item(),2))


print('\nerror:')
print('alpha1: ', round((1-round(dinn.alpha1.item(),2))/1,2)*100,'%')
print('alpha2: ', round((0-round(dinn.alpha2.item(),2))/1e-20,2)*100,'%')
print('beta: ', round((0.0075-round(dinn.beta.item(),4))/0.0075,2)*100,'%')
print('mu: ', round((5-round(dinn.mu.item(),2))/5,2)*100,'%')
print('u: ', round((0.515151515-round(dinn.u.item(),2))/0.515151515,2)*100,'%')
print('tao: ', round((0.58-round(dinn.tao.item(),2))/0.58,2)*100,'%')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-bc19c0a328ce> in <module>
# ----> 1 -print('alpha1: (goal 1)', round(dinn.alpha1.item(),2))
#       2 print('\nalpha2: (goal 0)', round(dinn.alpha2.item(),2))
#       3 print('\nbeta: (goal 0.0075): ', round(dinn.beta.item(),4))
#       4 print('\nmu (goal 5): ', round(dinn.mu.item(),2))
#       5 print('\nu: (goal 0.515151515): ', round(dinn.u.item(),2))
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     946                 return modules[name]
#     947         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 948             type(self).__name__, name))
#     949
#     950     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# AttributeError: 'DINN' object has no attribute 'alpha1'

# %%
#vaccination! 

import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial number of infected individuals, I0
I0 = 1
# Everyone else, S0, is susceptible to infection initially.
S0 = 2000
# Contact rate, beta, and mean recovery rate, mu.
beta, mu = dinn.beta, dinn.mu
# A grid of time points (in days)
t = np.linspace(0, 3, 100) 
#parameters
u = dinn.u
tao = dinn.tao
alpha1 = dinn.alpha1
alpha2 = dinn.alpha2

# The SIR model differential equations.
def deriv(y, t, beta, mu, u, tao, alpha1, alpha2):
    S, I = y
    dSdt = -beta * S * I + u * (t > tao) * alpha1 * (-S)
    dIdt = beta * S * I - mu * I + u * (t > tao) * alpha2 * (-I)
    return dSdt, dIdt

#add u = 0.5, get the corresponding tao, generate the SI data
# learn u (self.u), the corresponding tao (self.tao)

# Initial conditions vector
y0 = S0, I0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(beta, mu, u, tao, alpha1, alpha2))
S, I = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.plot(tSI_vaccination_data[0], tSI_vaccination_data[1], 'navy', alpha=0.9, lw=2, label='Actual Susceptible')
ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(tSI_vaccination_data[0], tSI_vaccination_data[2], 'dodgerblue', alpha=0.9, lw=2, label='Actual Infected')
ax.plot(t, I, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.set_xlabel('Time /days')
#ax.set_ylabel('Number (1000s)')
#ax.set_ylim(0,1.2)
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#calculate relative MSE loss
import math

S_total_loss = 0
S_den = 0
I_total_loss = 0
I_den = 0
for timestep in range(len(t)):
  S_value = tSI_vaccination_data[1][timestep] - S[timestep]
  S_total_loss += S_value**2
  S_den += (tSI_vaccination_data[1][timestep])**2
  I_value = tSI_vaccination_data[2][timestep] - I[timestep]
  I_total_loss += I_value**2
  I_den += (tSI_vaccination_data[2][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)

I_total_loss = math.sqrt(I_total_loss/I_den)
print('S_total_loss: ', S_total_loss)
print('I_total_loss: ', I_total_loss)
